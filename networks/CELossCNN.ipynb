# %%
# Adapted from: Chapter 7 and 8 of Deep Learning with Pytorch by Eli Stevens (2020)
try:
    import torch as t
    import torch.nn as tnn
except ImportError:
    print("Colab users: pytorch comes preinstalled. Select Change Ru")
    print("Local users: Please install pytorch for your hardware using instructions from here: https://pytorch.org/get-started/locally/")
    print("ACG users: Please follow instructions here: https://vikasdhiman.info/ECE490-Neural-Networks/posts/0000-00-06-acg-slurm-jupyter/")
    
    raise

if t.cuda.is_available():
    DEVICE="cuda"
    t.cuda.set_device(t.device('cuda:0'))
else:
    DEVICE="cpu"

    
DTYPE = t.get_default_dtype()
print(f"Using {DEVICE=} and {DTYPE=}")
# Out:
# Using DEVICE='cuda' and DTYPE=torch.float32

# %%
# imports
import torch.nn
import torch.optim
import torchvision
from torchvision.transforms import Compose, Normalize, Resize
from torchvision.transforms.functional import to_tensor
from torch.utils.data import DataLoader, Dataset
from glob import glob
from PIL import Image
import re
import random
from pathlib import Path

# %%
# create a custom dataset for the images
class BiomeDataset(Dataset):
    """
    Dataset for the minecraft biome images
    """
    def __init__(self, data_dir: str, dir_is_paths=False, id_convert_dict=None):
        """
        Arguments:
            data_dir (str): Path to root data directory
            dir_is_paths (bool): If true, interprets data_dir as a list of images
        """
        # init transform to none
        self.transform = None

        if id_convert_dict is not None:
            self.id_to_class = id_convert_dict

        if dir_is_paths:
            self.paths = data_dir
            return
    
        # get the number of images in the dataset
        self.paths = glob(f"{data_dir}/*/*")
        dirs = glob(f"{data_dir}/*")

        self.id_to_class = {} # dictionary which converts a biome id to its class number
        self.data = []  # 2d array. First index indexes biome, second index indexes images
        for i, d in enumerate(dirs):
            self.data.append(glob(f"{d}/*"))
            self.id_to_class[int(re.search(r'[0-9]+', d)[0])] = i

        print(self.id_to_class) 
        print(len(self.id_to_class))   


    def split_data(self, percent_train: float, percent_val: float, seed: int):
        """
        Splits the Dataset per biome into three separate Datasets, 
        one for training, one for validation, and the remainder is for testing.
        """
        train = []
        val = []
        test = []

        rand = random.Random(seed) # TODO: broken af

        # for each biome, randomize the list and then split it
        for b in self.data:
            n_ims = len(b)
            rand.shuffle(b)
            ind1 = int(n_ims * percent_train)
            ind2 = int(n_ims * (percent_train +percent_val))
            train += b[:ind1]
            val += b[ind1:ind2]
            test += b[ind2:]

        return (BiomeDataset(train, dir_is_paths=True, id_convert_dict=self.id_to_class), 
            BiomeDataset(val, dir_is_paths=True, id_convert_dict=self.id_to_class),
            BiomeDataset(test, dir_is_paths=True, id_convert_dict=self.id_to_class))

    
    def get_class_sizes(self, id_to_class: dict):
        """
        Returns a list ordered by class type (0-n_classes) where each element is
        the number of classes for that type. Used by the balanced_loss.py module
        
        Uses the id_to_class dict to convert the file paths to class numbers
        """
        sizes = [0 for i in list(id_to_class.keys())] # init to zero
        for p in self.paths:
            label = int(re.search(r'[0-9]+', p)[0])
            sizes[id_to_class[label]] += 1
        return sizes
            
    
    def set_transform(self, transform):
        """
        updates the transform that the dataset will use when transforming images
        """
        self.transform = transform


    def __getitem__(self, idx):
        """
        Returns a tuple of (image: ndarray, label: int)
        """

        imname = self.paths[idx]
        image = Image.open(imname)
        image = to_tensor(image).cuda()  # converts to float tensor
        # apply transforms
        if self.transform is not None:
            image = self.transform(image)
    
        label = int(re.search(r'[0-9]+', imname)[0])
        label = self.id_to_class[label]
        return (image, label)


    def __len__(self):
        return len(self.paths)


all_data = BiomeDataset('../scraping/preprocessed_data')
# Out:
# {27: 0, 21: 1, 11: 2, 156: 3, 4: 4, 39: 5, 32: 6, 16: 7, 34: 8, 13: 9, 35: 10, 3: 11, 6: 12, 131: 13, 37: 14, 7: 15, 22: 16, 17: 17, 158: 18, 18: 19, 45: 20, 31: 21, 29: 22, 157: 23, 28: 24, 132: 25, 26: 26, 33: 27, 1: 28, 12: 29, 162: 30, 130: 31, 36: 32, 19: 33, 129: 34, 5: 35, 30: 36, 38: 37, 133: 38, 2: 39, 10: 40}
# 41

# %%
# example image from the dataset
import matplotlib.pyplot as plt
im, label = all_data[3]
plt.imshow(im.cpu().permute(1, 2, 0))

# %%
# split up the data
train_data, val_data, test_data = all_data.split_data(0.7, 0.2, 5)
train_data[0][0].shape
# Out:
# torch.Size([3, 180, 320])

# %%
# Normalize the data over each channel
DATA_INFO_FILE = "dataset_info.txt"
if Path(DATA_INFO_FILE).exists():
    print('Loading known dataset information for normalization')
    
    means = torch.Tensor([0, 0, 0])
    std = torch.Tensor([0, 0, 0])
    with open(DATA_INFO_FILE, 'r') as f:
        m = f.readline().replace('\n', '').split(' ')
        means[0] = float(m[0])
        means[1] = float(m[1])
        means[2] = float(m[2])
        s = f.readline().replace('\n', '').split(' ')
        std[0] = float(s[0])# * 4 # TODO: Temporary hack to reduce exploding gradient problems
        std[1] = float(s[1])# * 4
        std[2] = float(s[2])# * 4
        print("Loaded means", m)
        print("Loaded std", s)

else:
    # compute the means across each channel for the whole training dataset
    means = torch.Tensor([0, 0, 0]).cuda()
    for i in range(len(train_data)):
        im = train_data[i][0]
        means += torch.mean(im, dim=[1,2]) 
        if i % 1000 == 0:
            print(f"Calculating dataset means: {i}/{len(train_data)}")

    means = means / i

    print(means)

    # compute the stdev across each channel for the whole training dataset
    sumel = 0.0
    countel = 0
    for i in range(len(train_data)):
        img = train_data[i][0]
        img = (img - means.unsqueeze(1).unsqueeze(1))**2
        sumel += img.sum([1, 2])
        countel += torch.numel(img[0])
        if i % 1000 == 0:
            print(f"Calculating dataset stdevs: {i}/{len(train_data)}")

    std = torch.sqrt(sumel/countel)

    print(std)

    # save dataset info so that it doesn't need to be recalculated
    with open(DATA_INFO_FILE, 'w') as f:
        f.write(f"{means[0]} {means[1]} {means[2]}\n")
        f.write(f"{std[0]} {std[1]} {std[2]}\n")
        
# normalize the training and validation datasets based on the mean and stedv 
# of the training dataset
# IMAGE_SIZE = (720//10, 1280//10)
transform_img = Compose([
    # Resize(IMAGE_SIZE, antialias=True), # ensure all images are the proper size
    Normalize(mean=means, std=std)
])

train_data.set_transform(transform_img)
val_data.set_transform(transform_img)
test_data.set_transform(transform_img)

# get the number of instances of each class in the training set
training_class_counts = train_data.get_class_sizes(all_data.id_to_class)
print(training_class_counts)
# Out:
# Loading known dataset information for normalization
# Loaded means ['0.38232675194740295', '0.44096899032592773', '0.44938528537750244']
# Loaded std ['0.2428676337003708', '0.2687499225139618', '0.38880330324172974']
# [571, 210, 33, 16, 1906, 29, 189, 298, 428, 331, 701, 1726, 465, 54, 75, 277, 100, 331, 4, 495, 12, 62, 567, 42, 197, 88, 79, 62, 2108, 877, 75, 58, 113, 247, 121, 1117, 226, 42, 25, 1071, 71]

# %%
# now a glance at the normalized data. 
im, label = train_data[1]
print(torch.min(im))
print(torch.max(im))

plt.imshow(im.cpu().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(-1.6408, device='cuda:0')
# tensor(2.0104, device='cuda:0')

# %%
# Hyperparameters
hyperparams = {
    "batch_size": 64,
    "learning_rate": 1e-3,
    "epochs": 300,
    "momentum": 0.9,
    "weight_decay": 0.01, # The L-2 normalization penalty used by the optimizer
    "dropout_rate": 0,
    "loss_f": "CrossEntropyLoss"
}

# Create the dataloaders. drop_last=True ignores the last, incomplete batch for evaluation compatibility
training_dataloader = DataLoader(train_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)
validation_dataloader = DataLoader(val_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)
test_dataloader = DataLoader(test_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)

# %%
# Model definition
loss = torch.nn.CrossEntropyLoss()

class ConvNeuralNet(tnn.Module):
    #  Determine what layers and their order in CNN object
    # Code from https://blog.paperspace.com/writing-cnns-from-scratch-in-pytorch/
    def __init__(self, num_classes, dropout_rate):
        super(ConvNeuralNet, self).__init__()
        self.conv_layer1 = tnn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, padding='same')
        self.drop1 = tnn.Dropout(dropout_rate)
        self.conv_layer2 = tnn.Conv2d(in_channels=16, out_channels=16, kernel_size=5, padding='same')
        self.batch_norm1 = tnn.BatchNorm2d(16)
        self.max_pool1 = tnn.MaxPool2d(kernel_size = 2, stride = 2)
        
        self.conv_layer3 = tnn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same')
        self.drop2 = tnn.Dropout(dropout_rate)
        self.conv_layer4 = tnn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding='same')
        self.batch_norm2 = tnn.BatchNorm2d(32)
        self.max_pool2 = tnn.MaxPool2d(kernel_size = 2, stride = 2)

        self.conv_layer5 = tnn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding='same')
        self.drop3 = tnn.Dropout(dropout_rate)
        self.conv_layer6 = tnn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same')
        self.batch_norm3 = tnn.BatchNorm2d(64)
        self.max_pool3 = tnn.MaxPool2d(kernel_size = 2, stride = 2)        

        self.conv_layer7 = tnn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding='same')
        self.drop4 = tnn.Dropout(dropout_rate)
        self.conv_layer8 = tnn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same')
        self.batch_norm4 = tnn.BatchNorm2d(128)
        self.max_pool4 = tnn.MaxPool2d(kernel_size = 2, stride = 2)    
        
        self.fc1 = tnn.Linear(28160, 128)
        self.relu1 = tnn.ReLU()
        self.dropend = tnn.Dropout(p=0.5) # accordding to literature, in FC layers dropout=0.5 is best
        self.fc2 = tnn.Linear(128, num_classes)
    
    # Progresses data across layers    
    def forward(self, x):
        out = self.conv_layer1(x)
        out = self.drop1(out)
        out = self.conv_layer2(out)
        out = self.batch_norm1(out)
        out = self.max_pool1(out)
        
        out = self.conv_layer3(out)
        out = self.drop2(out)
        out = self.conv_layer4(out)
        out = self.batch_norm2(out)
        out = self.max_pool2(out)
        
        out = self.conv_layer5(out)
        out = self.drop3(out)
        out = self.conv_layer6(out)
        out = self.batch_norm3(out)
        out = self.max_pool3(out)

        out = self.conv_layer7(out)
        out = self.drop4(out)
        out = self.conv_layer8(out)
        out = self.batch_norm4(out)
        out = self.max_pool4(out)
        
        out = out.reshape(out.size(0), -1)
        
        out = self.fc1(out)
        out = self.relu1(out)
        out = self.dropend(out)
        out = self.fc2(out)
        return out

    # Get model results for inputs
    def step(self, inputs):
        data, labels = inputs
        outputs = self(data)
        _, preds = torch.max(outputs.data , 1)
        return preds, labels
    
    # get predictions for entire dataloader
    def predict(self, dataloader):
        predictions = torch.Tensor()
        labels = torch.Tensor()
        self.eval() # put in eval mode
        for i, batch in enumerate(dataloader):
            pred, label = self.step(batch)
            predictions = torch.cat((predictions, pred.cpu()))
            labels = torch.cat((labels, label.cpu()))
        return predictions, labels
    
    
model = ConvNeuralNet(len(training_class_counts), hyperparams['dropout_rate'])
model.cuda()

# Define optimizer
optimizer = torch.optim.SGD(model.parameters(), 
                            lr=hyperparams['learning_rate'], 
                            momentum=hyperparams['momentum'], 
                            weight_decay=hyperparams['weight_decay']
                            )

# deine learning rate scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, mode='min',
                            patience=10, factor=0.5
                            )

# check what device model is being stored on
print("Is cuda being used for the model?", all([p.is_cuda for p in model.parameters()]))
# Out:
# Is cuda being used for the model? True

# %%
from torch.utils.tensorboard import SummaryWriter
import os, datetime
writer = SummaryWriter()

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def loss_and_accuracy(model, loss, validation_dataloader, device=DEVICE):
        # Validation loop
        validation_size = len(validation_dataloader.dataset)
        num_batches = len(validation_dataloader)
        test_loss, correct = 0, 0
        
        with torch.no_grad():
            model.eval() # Put model in eval mode, affects layers like dropout and batchnorm
            for X, y in validation_dataloader:
                X = X.to(device)
                y = y.to(device)
                pred = model(X)
                test_loss += loss(pred, y)
                correct += (pred.argmax(dim=-1) == y).type(DTYPE).sum()

        test_loss /= num_batches
        correct /= validation_size
        return test_loss, correct
    
def train(model, loss, training_dataloader, validation_dataloader, epochs, device=DEVICE, chkpt_name='model_ckpt.pt', ignore_chkpt=False):
    model.to(device)
    t0 = 0
    if not ignore_chkpt and os.path.exists(f"runs/{chkpt_name}"):
        checkpoint = torch.load(f"runs/{chkpt_name}")
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        t0 = checkpoint['epoch']
        
    # Keep track of train and val losses so that we can plot it easily after the training is complete
    train_losses = []
    val_losses = []
    
    for t in range(t0, epochs):
        # Train loop
        training_size = len(training_dataloader.dataset)
        nbatches = len(training_dataloader)
        model.train() # Put model in train mode, affects layers like dropout and batchnorm
        for batch, (X, y) in enumerate(training_dataloader):
            X = X.to(device)
            y = y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss_t = loss(pred, y)

            # Backpropagation
            optimizer.zero_grad()
            loss_t.backward()
            optimizer.step()

            if batch % 1 == 0:
                writer.add_scalar("Train/loss_batch", loss_t,  t*nbatches + batch)
                loss_t, current = loss_t.item(), (batch + 1) * len(X)
                print(f"loss: {loss_t:>7f}  [{current:>5d}/{training_size:>5d}]", end="\r")
                
        writer.add_scalar("Train/loss", loss_t, t)
        valid_loss, correct = loss_and_accuracy(model, loss, validation_dataloader, device=device)
        
        # step the learning rate shceduler
        scheduler.step(valid_loss)
        
        writer.add_scalar("Valid/loss", valid_loss, t)
        writer.add_scalar("Valid/accuracy", correct, t)
        print(f"\nValidation Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {valid_loss:>8f}. Learning rate: {get_lr(optimizer):>8f}. Completed epoch {t+1}/{epochs} \n")
        
        train_losses.append(float(loss_t))
        val_losses.append(float(valid_loss))
        
        if t % 3 == 0:
            torch.save({
                'epoch': t,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict()
                }, f"runs/{chkpt_name}")
    return model, train_losses, val_losses
        
    
print(f"Training model using device {DEVICE}. Started at {datetime.datetime.now()}")
trained_model, train_losses, val_losses = train(model, loss, training_dataloader, validation_dataloader, 
                    hyperparams['epochs'], chkpt_name='linear_model_chkpt.pt', ignore_chkpt=True)
# Out:
# Training model using device cuda. Started at 2023-04-26 15:34:44.951339
# loss: 2.023386  [15488/15499]
# Validation Error:
#  Accuracy: 54.1%, Avg loss: 1.735185. Learning rate: 0.001000. Completed epoch 1/300
#
# loss: 1.771453  [15488/15499]
# Validation Error:
#  Accuracy: 56.3%, Avg loss: 1.506965. Learning rate: 0.001000. Completed epoch 2/300
#
# loss: 1.610838  [15488/15499]
# Validation Error:
#  Accuracy: 50.5%, Avg loss: 1.692060. Learning rate: 0.001000. Completed epoch 3/300
#
# loss: 1.602857  [15488/15499]
# Validation Error:
#  Accuracy: 58.1%, Avg loss: 1.413140. Learning rate: 0.001000. Completed epoch 4/300
#
# loss: 1.374691  [15488/15499]
# Validation Error:
#  Accuracy: 61.8%, Avg loss: 1.265732. Learning rate: 0.001000. Completed epoch 5/300
#
# loss: 1.400284  [15488/15499]
# Validation Error:
#  Accuracy: 61.5%, Avg loss: 1.280998. Learning rate: 0.001000. Completed epoch 6/300
#
# loss: 1.028436  [15488/15499]
# Validation Error:
#  Accuracy: 61.9%, Avg loss: 1.297323. Learning rate: 0.001000. Completed epoch 7/300
#
# loss: 1.544985  [15488/15499]
# Validation Error:
#  Accuracy: 57.9%, Avg loss: 1.379883. Learning rate: 0.001000. Completed epoch 8/300
#
# loss: 1.235546  [15488/15499]
# Validation Error:
#  Accuracy: 65.0%, Avg loss: 1.187701. Learning rate: 0.001000. Completed epoch 9/300
#
# loss: 1.272823  [15488/15499]
# Validation Error:
#  Accuracy: 65.0%, Avg loss: 1.125894. Learning rate: 0.001000. Completed epoch 10/300
#
# loss: 1.180862  [15488/15499]
# Validation Error:
#  Accuracy: 67.5%, Avg loss: 1.070188. Learning rate: 0.001000. Completed epoch 11/300
#
# loss: 0.927900  [15488/15499]
# Validation Error:
#  Accuracy: 64.3%, Avg loss: 1.148189. Learning rate: 0.001000. Completed epoch 12/300
#
# loss: 1.147838  [15488/15499]
# Validation Error:
#  Accuracy: 65.0%, Avg loss: 1.157346. Learning rate: 0.001000. Completed epoch 13/300
#
# loss: 1.053302  [15488/15499]
# Validation Error:
#  Accuracy: 67.6%, Avg loss: 1.051828. Learning rate: 0.001000. Completed epoch 14/300
[15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916076. Learning rate: 0.000004. Completed epoch 148/300
#
# loss: 0.126594  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.916837. Learning rate: 0.000004. Completed epoch 149/300
#
# loss: 0.222315  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.917592. Learning rate: 0.000004. Completed epoch 150/300
#
# loss: 0.194014  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916213. Learning rate: 0.000004. Completed epoch 151/300
#
# loss: 0.210706  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.913562. Learning rate: 0.000004. Completed epoch 152/300
#
# loss: 0.201525  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917243. Learning rate: 0.000004. Completed epoch 153/300
#
# loss: 0.145110  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917083. Learning rate: 0.000002. Completed epoch 154/300
#
# loss: 0.179705  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.915282. Learning rate: 0.000002. Completed epoch 155/300
#
# loss: 0.124992  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915982. Learning rate: 0.000002. Completed epoch 156/300
#
# loss: 0.191206  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915911. Learning rate: 0.000002. Completed epoch 157/300
#
# loss: 0.276036  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918153. Learning rate: 0.000002. Completed epoch 158/300
#
# loss: 0.186264  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915058. Learning rate: 0.000002. Completed epoch 159/300
#
# loss: 0.133526  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915558. Learning rate: 0.000002. Completed epoch 160/300
#
# loss: 0.204930  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.914822. Learning rate: 0.000002. Completed epoch 161/300
#
# loss: 0.231347  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916065. Learning rate: 0.000002. Completed epoch 162/300
#
# loss: 0.259996  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917258. Learning rate: 0.000002. Completed epoch 163/300
#
# loss: 0.173193  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.918646. Learning rate: 0.000002. Completed epoch 164/300
#
# loss: 0.189014  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916572. Learning rate: 0.000001. Completed epoch 165/300
#
# loss: 0.170461  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917003. Learning rate: 0.000001. Completed epoch 166/300
#
# loss: 0.184169  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.919335. Learning rate: 0.000001. Completed epoch 167/300
#
# loss: 0.187328  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918894. Learning rate: 0.000001. Completed epoch 168/300
#
# loss: 0.194818  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916404. Learning rate: 0.000001. Completed epoch 169/300
#
# loss: 0.213975  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.914019. Learning rate: 0.000001. Completed epoch 170/300
#
# loss: 0.163022  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915989. Learning rate: 0.000001. Completed epoch 171/300
#
# loss: 0.202624  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.915800. Learning rate: 0.000001. Completed epoch 172/300
#
# loss: 0.143575  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915329. Learning rate: 0.000001. Completed epoch 173/300
#
# loss: 0.212334  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916799. Learning rate: 0.000001. Completed epoch 174/300
#
# loss: 0.269757  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915668. Learning rate: 0.000001. Completed epoch 175/300
#
# loss: 0.254757  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.916746. Learning rate: 0.000000. Completed epoch 176/300
#
# loss: 0.233495  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916044. Learning rate: 0.000000. Completed epoch 177/300
#
# loss: 0.212158  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915796. Learning rate: 0.000000. Completed epoch 178/300
#
# loss: 0.264887  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.911178. Learning rate: 0.000000. Completed epoch 179/300
#
# loss: 0.211133  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917692. Learning rate: 0.000000. Completed epoch 180/300
# loss: 0.257194  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917083. Learning rate: 0.000000. Completed epoch 181/300
#
# loss: 0.274615  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.914227. Learning rate: 0.000000. Completed epoch 182/300
#
# loss: 0.219692  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.914397. Learning rate: 0.000000. Completed epoch 183/300
#
# loss: 0.168544  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.912331. Learning rate: 0.000000. Completed epoch 184/300
#
# loss: 0.221274  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917451. Learning rate: 0.000000. Completed epoch 185/300
#
# loss: 0.214534  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915744. Learning rate: 0.000000. Completed epoch 186/300
#
# loss: 0.240807  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.918583. Learning rate: 0.000000. Completed epoch 187/300
#
# loss: 0.159017  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.912692. Learning rate: 0.000000. Completed epoch 188/300
#
# loss: 0.302672  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.912404. Learning rate: 0.000000. Completed epoch 189/300
#
# loss: 0.149801  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916354. Learning rate: 0.000000. Completed epoch 190/300
#
# loss: 0.331924  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.912369. Learning rate: 0.000000. Completed epoch 191/300
#
# loss: 0.277993  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915534. Learning rate: 0.000000. Completed epoch 192/300
#
# loss: 0.247634  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916254. Learning rate: 0.000000. Completed epoch 193/300
#
# loss: 0.229112  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.918772. Learning rate: 0.000000. Completed epoch 194/300
#
# loss: 0.248741  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916954. Learning rate: 0.000000. Completed epoch 195/300
#
# loss: 0.183782  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915158. Learning rate: 0.000000. Completed epoch 196/300
#
# loss: 0.220759  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918535. Learning rate: 0.000000. Completed epoch 197/300
#
# loss: 0.226277  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.916538. Learning rate: 0.000000. Completed epoch 198/300
#
# loss: 0.142164  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917647. Learning rate: 0.000000. Completed epoch 199/300
#
# loss: 0.204238  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916803. Learning rate: 0.000000. Completed epoch 200/300
#
# loss: 0.205303  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914707. Learning rate: 0.000000. Completed epoch 201/300
#
# loss: 0.306097  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917334. Learning rate: 0.000000. Completed epoch 202/300
#
# loss: 0.260384  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914950. Learning rate: 0.000000. Completed epoch 203/300
#
# loss: 0.203018  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915402. Learning rate: 0.000000. Completed epoch 204/300
#
# loss: 0.163988  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.917925. Learning rate: 0.000000. Completed epoch 205/300
#
# loss: 0.193530  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917223. Learning rate: 0.000000. Completed epoch 206/300
#
# loss: 0.212470  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916223. Learning rate: 0.000000. Completed epoch 207/300
#
# loss: 0.226851  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915747. Learning rate: 0.000000. Completed epoch 208/300
#
# loss: 0.368989  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.915237. Learning rate: 0.000000. Completed epoch 209/300
#
# loss: 0.206859  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.913701. Learning rate: 0.000000. Completed epoch 210/300
#
# loss: 0.167912  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.913033. Learning rate: 0.000000. Completed epoch 211/300
#
# loss: 0.267478  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917603. Learning rate: 0.000000. Completed epoch 212/300
#
# loss: 0.189674  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.915077. Learning rate: 0.000000. Completed epoch 213/300
#
# loss: 0.243352  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915573. Learning rate: 0.000000. Completed epoch 214/300
#
# loss: 0.181382  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915185. Learning rate: 0.000000. Completed epoch 215/300
#
# loss: 0.199450  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916370. Learning rate: 0.000000. Completed epoch 216/300
#
# loss: 0.163613  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914953. Learning rate: 0.000000. Completed epoch 217/300
#
# loss: 0.186565  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.915651. Learning rate: 0.000000. Completed epoch 218/300
#
# loss: 0.162564  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.916031. Learning rate: 0.000000. Completed epoch 219/300
#
# loss: 0.122942  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916181. Learning rate: 0.000000. Completed epoch 220/300
#
# loss: 0.173778  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.911554. Learning rate: 0.000000. Completed epoch 221/300
#
# loss: 0.255343  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915962. Learning rate: 0.000000. Completed epoch 222/300
#
# loss: 0.235413  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915534. Learning rate: 0.000000. Completed epoch 223/300
#
# loss: 0.226644  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.913258. Learning rate: 0.000000. Completed epoch 224/300
#
# loss: 0.190237  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915395. Learning rate: 0.000000. Completed epoch 225/300
#
# loss: 0.183967  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.916609. Learning rate: 0.000000. Completed epoch 226/300
#
# loss: 0.150412  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917274. Learning rate: 0.000000. Completed epoch 227/300
#
# loss: 0.271772  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917498. Learning rate: 0.000000. Completed epoch 228/300
#
# loss: 0.218598  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.913673. Learning rate: 0.000000. Completed epoch 229/300
#
# loss: 0.239556  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915620. Learning rate: 0.000000. Completed epoch 230/300
#
# loss: 0.162004  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918711. Learning rate: 0.000000. Completed epoch 231/300
#
# loss: 0.526513  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.913737. Learning rate: 0.000000. Completed epoch 232/300
#
# loss: 0.310667  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917144. Learning rate: 0.000000. Completed epoch 233/300
#
# loss: 0.210351  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915101. Learning rate: 0.000000. Completed epoch 234/300
#
# loss: 0.247721  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917449. Learning rate: 0.000000. Completed epoch 235/300
#
# loss: 0.275089  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.914800. Learning rate: 0.000000. Completed epoch 236/300
#
# loss: 0.233740  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.917298. Learning rate: 0.000000. Completed epoch 237/300
#
# loss: 0.165787  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915979. Learning rate: 0.000000. Completed epoch 238/300
#
# loss: 0.184201  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916284. Learning rate: 0.000000. Completed epoch 239/300
#
# loss: 0.255261  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914320. Learning rate: 0.000000. Completed epoch 240/300
# loss: 0.241933  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914484. Learning rate: 0.000000. Completed epoch 241/300
#
# loss: 0.194442  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918296. Learning rate: 0.000000. Completed epoch 242/300
#
# loss: 0.226894  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.918665. Learning rate: 0.000000. Completed epoch 243/300
#
# loss: 0.221750  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915820. Learning rate: 0.000000. Completed epoch 244/300
#
# loss: 0.170015  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916750. Learning rate: 0.000000. Completed epoch 245/300
#
# loss: 0.245735  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915909. Learning rate: 0.000000. Completed epoch 246/300
#
# loss: 0.206271  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.919718. Learning rate: 0.000000. Completed epoch 247/300
#
# loss: 0.258203  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916787. Learning rate: 0.000000. Completed epoch 248/300
#
# loss: 0.287581  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.918600. Learning rate: 0.000000. Completed epoch 249/300
#
# loss: 0.172733  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915546. Learning rate: 0.000000. Completed epoch 250/300
#
# loss: 0.183107  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914872. Learning rate: 0.000000. Completed epoch 251/300
#
# loss: 0.212461  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917627. Learning rate: 0.000000. Completed epoch 252/300
#
# loss: 0.182562  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917065. Learning rate: 0.000000. Completed epoch 253/300
#
# loss: 0.344379  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.912075. Learning rate: 0.000000. Completed epoch 254/300
#
# loss: 0.280814  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916882. Learning rate: 0.000000. Completed epoch 255/300
#
# loss: 0.158804  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.914980. Learning rate: 0.000000. Completed epoch 256/300
#
# loss: 0.220857  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.912799. Learning rate: 0.000000. Completed epoch 257/300
#
# loss: 0.237951  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916501. Learning rate: 0.000000. Completed epoch 258/300
#
# loss: 0.282902  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.919336. Learning rate: 0.000000. Completed epoch 259/300
#
# loss: 0.165541  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916464. Learning rate: 0.000000. Completed epoch 260/300
#
# loss: 0.178390  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.914840. Learning rate: 0.000000. Completed epoch 261/300
#
# loss: 0.267312  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914889. Learning rate: 0.000000. Completed epoch 262/300
#
# loss: 0.203505  [15488/15499]
# Validation Error:
#  Accuracy: 73.0%, Avg loss: 0.915132. Learning rate: 0.000000. Completed epoch 263/300
#
# loss: 0.332252  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918383. Learning rate: 0.000000. Completed epoch 264/300
#
# loss: 0.164635  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.920605. Learning rate: 0.000000. Completed epoch 265/300
#
# loss: 0.151558  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.914140. Learning rate: 0.000000. Completed epoch 266/300
#
# loss: 0.284042  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916321. Learning rate: 0.000000. Completed epoch 267/300
#
# loss: 0.180467  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918359. Learning rate: 0.000000. Completed epoch 268/300
#
# loss: 0.226613  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917945. Learning rate: 0.000000. Completed epoch 269/300
#
# loss: 0.252664  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915814. Learning rate: 0.000000. Completed epoch 270/300
#
# loss: 0.151728  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915965. Learning rate: 0.000000. Completed epoch 271/300
#
# loss: 0.240603  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.914564. Learning rate: 0.000000. Completed epoch 272/300
#
# loss: 0.199188  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.915955. Learning rate: 0.000000. Completed epoch 273/300
#
# loss: 0.131748  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.919142. Learning rate: 0.000000. Completed epoch 274/300
#
# loss: 0.175510  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916355. Learning rate: 0.000000. Completed epoch 275/300
#
# loss: 0.127215  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916433. Learning rate: 0.000000. Completed epoch 276/300
#
# loss: 0.174504  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.916896. Learning rate: 0.000000. Completed epoch 277/300
#
# loss: 0.109850  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915216. Learning rate: 0.000000. Completed epoch 278/300
#
# loss: 0.167557  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914541. Learning rate: 0.000000. Completed epoch 279/300
#
# loss: 0.244372  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.912093. Learning rate: 0.000000. Completed epoch 280/300
#
# loss: 0.249353  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915471. Learning rate: 0.000000. Completed epoch 281/300
#
# loss: 0.192995  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916269. Learning rate: 0.000000. Completed epoch 282/300
#
# loss: 0.217490  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914738. Learning rate: 0.000000. Completed epoch 283/300
#
# loss: 0.154607  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.912355. Learning rate: 0.000000. Completed epoch 284/300
#
# loss: 0.174368  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915566. Learning rate: 0.000000. Completed epoch 285/300
#
# loss: 0.297594  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915696. Learning rate: 0.000000. Completed epoch 286/300
#
# loss: 0.174148  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914912. Learning rate: 0.000000. Completed epoch 287/300
#
# loss: 0.148493  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.915264. Learning rate: 0.000000. Completed epoch 288/300
#
# loss: 0.200435  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.915017. Learning rate: 0.000000. Completed epoch 289/300
#
# loss: 0.191403  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.913926. Learning rate: 0.000000. Completed epoch 290/300
#
# loss: 0.166106  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.913521. Learning rate: 0.000000. Completed epoch 291/300
#
# loss: 0.140539  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.914057. Learning rate: 0.000000. Completed epoch 292/300
#
# loss: 0.310510  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.913050. Learning rate: 0.000000. Completed epoch 293/300
#
# loss: 0.192334  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.913732. Learning rate: 0.000000. Completed epoch 294/300
#
# loss: 0.231519  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.917316. Learning rate: 0.000000. Completed epoch 295/300
#
# loss: 0.320912  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.918771. Learning rate: 0.000000. Completed epoch 296/300
#
# loss: 0.186852  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.912890. Learning rate: 0.000000. Completed epoch 297/300
#
# loss: 0.324410  [15488/15499]
# Validation Error:
#  Accuracy: 73.2%, Avg loss: 0.916924. Learning rate: 0.000000. Completed epoch 298/300
#
# loss: 0.167433  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.916008. Learning rate: 0.000000. Completed epoch 299/300
#
# loss: 0.265636  [15488/15499]
# Validation Error:
#  Accuracy: 73.4%, Avg loss: 0.917088. Learning rate: 0.000000. Completed epoch 300/300

# %%
import numpy as np
# plot the losses
def plot_losses(train_loss, val_loss):
    t_loss = np.asarray(train_loss, dtype=float)
    v_loss = np.asarray(val_loss, dtype=float)
    epochs = range(len(train_loss))
    
    plt.figure(figsize=(24, 6), dpi=80)
    plt.plot(epochs, t_loss, "b", label="Training loss")
    plt.plot(epochs, v_loss, "r", label="Validation loss")
    plt.title("Training and Validation Losses.")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.show()
    
plot_losses(train_losses, val_losses)

# %%
from modules import train_info as ti # custom module

import importlib
importlib.reload(ti) # ensure code changes are applied (otherwise jupyter does not reimport)
# Out:
# <module 'modules.train_info' from '/home/wcunningham/biome_detector/networks/modules/train_info.py'>

# %%
# Evaluate the model

pred, labels = model.predict(training_dataloader)
accuracies_train, accuracy_train = ti.per_class_accuracies(pred, labels)

print("Overall training accuracy:", accuracy_train)
#print("Training accuracy by class:\n", accuracies_train)

pred, labels = model.predict(test_dataloader)
accuracies_test, accuracy_test = ti.per_class_accuracies(pred, labels)

print("Overall testing accuracy:", accuracy_test)
#print("Training accuracy by class:\n", accuracies_test)
# Out:
# Overall training accuracy: 0.9830191115702479
# Overall testing accuracy: 0.7339285714285714

# %%
# calculate, save, and dispay information on this run
sizes = ti.get_class_sizes(all_data.data)

# train accuracies plot
ti.plot_accuracies(accuracies_train, sizes, "Training Data Accuracies by Class Size")
# test accuracies plot
ti.plot_accuracies(accuracies_test, sizes, "Testing Data Accuracies by Class Size")

# save the data to a json file
ti.write_info(hyperparams, accuracies_train, accuracies_test, sizes)
# Out:
# 'logs/trainlog_2023-04-26T19-55-29-705329.json'

# %%
# save the model out
saving = False
if saving:
    torch.save(trained_model.state_dict(), "detector_model.pt")
