# %%
# Adapted from: Chapter 7 and 8 of Deep Learning with Pytorch by Eli Stevens (2020)
try:
    import torch as t
    import torch.nn as tnn
except ImportError:
    print("Colab users: pytorch comes preinstalled. Select Change Ru")
    print("Local users: Please install pytorch for your hardware using instructions from here: https://pytorch.org/get-started/locally/")
    print("ACG users: Please follow instructions here: https://vikasdhiman.info/ECE490-Neural-Networks/posts/0000-00-06-acg-slurm-jupyter/")
    
    raise

if t.cuda.is_available():
    DEVICE="cuda"
    t.cuda.set_device(t.device('cuda:0'))
else:
    DEVICE="cpu"

    
DTYPE = t.get_default_dtype()
print(f"Using {DEVICE=} and {DTYPE=}")
# Out:
# Using DEVICE='cuda' and DTYPE=torch.float32

# %%
# imports
import torch.nn
import torch.optim
import torchvision
from torchvision.transforms import Compose, Normalize, Resize
from torchvision.transforms.functional import to_tensor
from torch.utils.data import DataLoader, Dataset
from glob import glob
from PIL import Image
import re
import random
from pathlib import Path

# %%
# create a custom dataset for the images
class BiomeDataset(Dataset):
    """
    Dataset for the minecraft biome images
    """
    def __init__(self, data_dir: str, dir_is_paths=False, id_convert_dict=None):
        """
        Arguments:
            data_dir (str): Path to root data directory
            dir_is_paths (bool): If true, interprets data_dir as a list of images
        """
        # init transform to none
        self.transform = None

        if id_convert_dict is not None:
            self.id_to_class = id_convert_dict

        if dir_is_paths:
            self.paths = data_dir
            return
    
        # get the number of images in the dataset
        self.paths = glob(f"{data_dir}/*/*")
        dirs = glob(f"{data_dir}/*")

        self.id_to_class = {} # dictionary which converts a biome id to its class number
        self.data = []  # 2d array. First index indexes biome, second index indexes images
        for i, d in enumerate(dirs):
            self.data.append(glob(f"{d}/*"))
            self.id_to_class[int(re.search(r'[0-9]+', d)[0])] = i

        print(self.id_to_class) 
        print(len(self.id_to_class))   


    def split_data(self, percent_train: float, percent_val: float, seed: int):
        """
        Splits the Dataset per biome into three separate Datasets, 
        one for training, one for validation, and the remainder is for testing.
        """
        train = []
        val = []
        test = []

        rand = random.Random(seed) # TODO: broken af

        # for each biome, randomize the list and then split it
        for b in self.data:
            n_ims = len(b)
            rand.shuffle(b)
            ind1 = int(n_ims * percent_train)
            ind2 = int(n_ims * (percent_train +percent_val))
            train += b[:ind1]
            val += b[ind1:ind2]
            test += b[ind2:]

        return (BiomeDataset(train, dir_is_paths=True, id_convert_dict=self.id_to_class), 
            BiomeDataset(val, dir_is_paths=True, id_convert_dict=self.id_to_class),
            BiomeDataset(test, dir_is_paths=True, id_convert_dict=self.id_to_class))

    
    def get_class_sizes(self, id_to_class: dict):
        """
        Returns a list ordered by class type (0-n_classes) where each element is
        the number of classes for that type. Used by the balanced_loss.py module
        
        Uses the id_to_class dict to convert the file paths to class numbers
        """
        sizes = [0 for i in list(id_to_class.keys())] # init to zero
        for p in self.paths:
            label = int(re.search(r'[0-9]+', p)[0])
            sizes[id_to_class[label]] += 1
        return sizes
            
    
    def set_transform(self, transform):
        """
        updates the transform that the dataset will use when transforming images
        """
        self.transform = transform


    def __getitem__(self, idx):
        """
        Returns a tuple of (image: ndarray, label: int)
        """

        imname = self.paths[idx]
        image = Image.open(imname)
        image = to_tensor(image).cuda()  # converts to float tensor
        # apply transforms
        if self.transform is not None:
            image = self.transform(image)
    
        label = int(re.search(r'[0-9]+', imname)[0])
        label = self.id_to_class[label]
        return (image, label)


    def __len__(self):
        return len(self.paths)


all_data = BiomeDataset('../scraping/preprocessed_data')
# Out:
# {27: 0, 21: 1, 11: 2, 156: 3, 4: 4, 39: 5, 32: 6, 16: 7, 34: 8, 13: 9, 35: 10, 3: 11, 6: 12, 131: 13, 37: 14, 7: 15, 22: 16, 17: 17, 158: 18, 18: 19, 45: 20, 31: 21, 29: 22, 157: 23, 28: 24, 132: 25, 26: 26, 33: 27, 1: 28, 12: 29, 162: 30, 130: 31, 36: 32, 19: 33, 129: 34, 5: 35, 30: 36, 38: 37, 133: 38, 2: 39, 10: 40}
# 41

# %%
# example image from the dataset
import matplotlib.pyplot as plt
im, label = all_data[3]
plt.imshow(im.cpu().permute(1, 2, 0))

# %%
# split up the data
train_data, val_data, test_data = all_data.split_data(0.7, 0.2, 5)
train_data[0][0].shape
# Out:
# torch.Size([3, 180, 320])

# %%
# Normalize the data over each channel
DATA_INFO_FILE = "dataset_info.txt"
if Path(DATA_INFO_FILE).exists():
    print('Loading known dataset information for normalization')
    
    means = torch.Tensor([0, 0, 0])
    std = torch.Tensor([0, 0, 0])
    with open(DATA_INFO_FILE, 'r') as f:
        m = f.readline().replace('\n', '').split(' ')
        means[0] = float(m[0])
        means[1] = float(m[1])
        means[2] = float(m[2])
        s = f.readline().replace('\n', '').split(' ')
        std[0] = float(s[0])# * 4 # TODO: Temporary hack to reduce exploding gradeint problems
        std[1] = float(s[1])# * 4
        std[2] = float(s[2])# * 4
        print("Loaded means", m)
        print("Loaded std", s)

else:
    # compute the means across each channel for the whole training dataset
    means = torch.Tensor([0, 0, 0]).cuda()
    for i in range(len(train_data)):
        im = train_data[i][0]
        means += torch.mean(im, dim=[1,2]) 
        if i % 1000 == 0:
            print(f"Calculating dataset means: {i}/{len(train_data)}")

    means = means / i

    print(means)

    # compute the stdev across each channel for the whole training dataset
    sumel = 0.0
    countel = 0
    for i in range(len(train_data)):
        img = train_data[i][0]
        img = (img - means.unsqueeze(1).unsqueeze(1))**2
        sumel += img.sum([1, 2])
        countel += torch.numel(img[0])
        if i % 1000 == 0:
            print(f"Calculating dataset stdevs: {i}/{len(train_data)}")

    std = torch.sqrt(sumel/countel)

    print(std)

    # save dataset info so that it doesn't need to be recalculated
    with open(DATA_INFO_FILE, 'w') as f:
        f.write(f"{means[0]} {means[1]} {means[2]}\n")
        f.write(f"{std[0]} {std[1]} {std[2]}\n")
        
# normalize the training and validation datasets based on the mean and stedv 
# of the training dataset
# IMAGE_SIZE = (720//10, 1280//10)
transform_img = Compose([
    # Resize(IMAGE_SIZE, antialias=True), # ensure all images are the proper size
    Normalize(mean=means, std=std)
])

train_data.set_transform(transform_img)
val_data.set_transform(transform_img)
test_data.set_transform(transform_img)

# get the number of instances of each class in the training set
training_class_counts = train_data.get_class_sizes(all_data.id_to_class)
print(training_class_counts)
# Out:
# Loading known dataset information for normalization
# Loaded means ['0.38232675194740295', '0.44096899032592773', '0.44938528537750244']
# Loaded std ['0.2428676337003708', '0.2687499225139618', '0.38880330324172974']
# [571, 210, 33, 16, 1906, 29, 189, 298, 428, 331, 701, 1726, 465, 54, 75, 277, 100, 331, 4, 495, 12, 62, 567, 42, 197, 88, 79, 62, 2108, 877, 75, 58, 113, 247, 121, 1117, 226, 42, 25, 1071, 71]

# %%
# now a glance at the normalized data. 
im, label = train_data[1]
print(torch.min(im))
print(torch.max(im))

plt.imshow(im.cpu().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(-1.6408, device='cuda:0')
# tensor(2.0104, device='cuda:0')

# %%
# Hyperparameters
hyperparams = {
    "batch_size": 64,
    "learning_rate": 1e-3,
    "epochs": 300,
    "momentum": 0.9,
    "weight_decay": 0.01, # The L-2 normalization penalty used by the optimizer
    "dropout_rate": 0,
    "loss_f": "FocalLoss",
    "gamma": 2,    # focal loss parameter. The paper found that gamma=2 was optimal for their network
    "beta": 0.99
}

# Create the dataloaders. drop_last=True ignores the last, incomplete batch for evaluation compatibility
training_dataloader = DataLoader(train_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)
validation_dataloader = DataLoader(val_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)
test_dataloader = DataLoader(test_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)

# %%
# Model definition
from modules.losses import Loss
#loss = focalloss.FocalLoss(hyperparams['gamma'], hyperparams['alpha']) # sed for binary classification?
loss = Loss(
    loss_type="focal_loss",
    beta=hyperparams['beta'], # class-balanced loss beta
    fl_gamma=hyperparams['gamma'], 
    samples_per_class=training_class_counts,
    class_balanced=True
    )

class ConvNeuralNet(tnn.Module):
    #  Determine what layers and their order in CNN object
    # Code from https://blog.paperspace.com/writing-cnns-from-scratch-in-pytorch/
    def __init__(self, num_classes, dropout_rate):
        super(ConvNeuralNet, self).__init__()
        self.conv_layer1 = tnn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, padding='same')
        self.drop1 = tnn.Dropout(dropout_rate)
        self.conv_layer2 = tnn.Conv2d(in_channels=16, out_channels=16, kernel_size=5, padding='same')
        self.batch_norm1 = tnn.BatchNorm2d(16)
        self.max_pool1 = tnn.MaxPool2d(kernel_size = 2, stride = 2)
        
        self.conv_layer3 = tnn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same')
        self.drop2 = tnn.Dropout(dropout_rate)
        self.conv_layer4 = tnn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding='same')
        self.batch_norm2 = tnn.BatchNorm2d(32)
        self.max_pool2 = tnn.MaxPool2d(kernel_size = 2, stride = 2)

        self.conv_layer5 = tnn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding='same')
        self.drop3 = tnn.Dropout(dropout_rate)
        self.conv_layer6 = tnn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same')
        self.batch_norm3 = tnn.BatchNorm2d(64)
        self.max_pool3 = tnn.MaxPool2d(kernel_size = 2, stride = 2)        

        self.conv_layer7 = tnn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding='same')
        self.drop4 = tnn.Dropout(dropout_rate)
        self.conv_layer8 = tnn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same')
        self.batch_norm4 = tnn.BatchNorm2d(128)
        self.max_pool4 = tnn.MaxPool2d(kernel_size = 2, stride = 2)    
        
        self.fc1 = tnn.Linear(28160, 128)
        self.relu1 = tnn.ReLU()
        self.dropend = tnn.Dropout(p=0.5) # accordding to literature, in FC layers dropout=0.5 is best
        self.fc2 = tnn.Linear(128, num_classes)
    
    # Progresses data across layers    
    def forward(self, x):
        out = self.conv_layer1(x)
        out = self.drop1(out)
        out = self.conv_layer2(out)
        out = self.batch_norm1(out)
        out = self.max_pool1(out)
        
        out = self.conv_layer3(out)
        out = self.drop2(out)
        out = self.conv_layer4(out)
        out = self.batch_norm2(out)
        out = self.max_pool2(out)
        
        out = self.conv_layer5(out)
        out = self.drop3(out)
        out = self.conv_layer6(out)
        out = self.batch_norm3(out)
        out = self.max_pool3(out)

        out = self.conv_layer7(out)
        out = self.drop4(out)
        out = self.conv_layer8(out)
        out = self.batch_norm4(out)
        out = self.max_pool4(out)
        
        out = out.reshape(out.size(0), -1)
        
        out = self.fc1(out)
        out = self.relu1(out)
        out = self.dropend(out)
        out = self.fc2(out)
        return out

    # Get model results for inputs
    def step(self, inputs):
        data, labels = inputs
        outputs = self(data)
        _, preds = torch.max(outputs.data , 1)
        return preds, labels
    
    # get predictions for entire dataloader
    def predict(self, dataloader):
        predictions = torch.Tensor()
        labels = torch.Tensor()
        self.eval() # put in eval mode
        for i, batch in enumerate(dataloader):
            pred, label = self.step(batch)
            predictions = torch.cat((predictions, pred.cpu()))
            labels = torch.cat((labels, label.cpu()))
        return predictions, labels
    
    
model = ConvNeuralNet(len(training_class_counts), hyperparams['dropout_rate'])
model.cuda()

# Define optimizer
optimizer = torch.optim.SGD(model.parameters(), 
                            lr=hyperparams['learning_rate'], 
                            momentum=hyperparams['momentum'], 
                            weight_decay=hyperparams['weight_decay']
                            )

# deine learning rate scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, mode='min',
                            patience=10
                            )

# check what device model is being stored on
print("Is cuda being used for the model?", all([p.is_cuda for p in model.parameters()]))
# Out:
# Is cuda being used for the model? True

# %%
from torch.utils.tensorboard import SummaryWriter
import os, datetime
writer = SummaryWriter()

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def loss_and_accuracy(model, loss, validation_dataloader, device=DEVICE):
        # Validation loop
        validation_size = len(validation_dataloader.dataset)
        num_batches = len(validation_dataloader)
        test_loss, correct = 0, 0
        
        with torch.no_grad():
            model.eval() # Put model in eval mode, affects layers like dropout and batchnorm
            for X, y in validation_dataloader:
                X = X.to(device)
                y = y.to(device)
                pred = model(X)
                test_loss += loss(pred, y)
                correct += (pred.argmax(dim=-1) == y).type(DTYPE).sum()

        test_loss /= num_batches
        correct /= validation_size
        return test_loss, correct
    
def train(model, loss, training_dataloader, validation_dataloader, epochs, device=DEVICE, chkpt_name='model_ckpt.pt', ignore_chkpt=False):
    model.to(device)
    t0 = 0
    if not ignore_chkpt and os.path.exists(f"runs/{chkpt_name}"):
        checkpoint = torch.load(f"runs/{chkpt_name}")
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        t0 = checkpoint['epoch']
        
    # Keep track of train and val losses so that we can plot it easily after the training is complete
    train_losses = []
    val_losses = []
    
    for t in range(t0, epochs):
        # Train loop
        training_size = len(training_dataloader.dataset)
        nbatches = len(training_dataloader)
        model.train() # Put model in train mode, affects layers like dropout and batchnorm
        for batch, (X, y) in enumerate(training_dataloader):
            X = X.to(device)
            y = y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss_t = loss(pred, y)

            # Backpropagation
            optimizer.zero_grad()
            loss_t.backward()
            optimizer.step()

            if batch % 1 == 0:
                writer.add_scalar("Train/loss_batch", loss_t,  t*nbatches + batch)
                loss_t, current = loss_t.item(), (batch + 1) * len(X)
                print(f"loss: {loss_t:>7f}  [{current:>5d}/{training_size:>5d}]", end="\r")
                
        writer.add_scalar("Train/loss", loss_t, t)
        valid_loss, correct = loss_and_accuracy(model, loss, validation_dataloader, device=device)
        
        # step the learning rate shceduler
        scheduler.step(valid_loss)
        
        writer.add_scalar("Valid/loss", valid_loss, t)
        writer.add_scalar("Valid/accuracy", correct, t)
        print(f"\nValidation Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {valid_loss:>8f}. Learning rate: {get_lr(optimizer):>8f}. Completed epoch {t+1}/{epochs} \n")
        

        
        train_losses.append(float(loss_t))
        val_losses.append(float(valid_loss))
        
        if t % 3 == 0:
            torch.save({
                'epoch': t,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict()
                }, f"runs/{chkpt_name}")
    return model, train_losses, val_losses
        
    
print(f"Training model using device {DEVICE}. Started at {datetime.datetime.now()}")
trained_model, train_losses, val_losses = train(model, loss, training_dataloader, validation_dataloader, 
                    hyperparams['epochs'], chkpt_name='linear_model_chkpt.pt', ignore_chkpt=True)
# Out:
# Training model using device cuda. Started at 2023-04-25 10:29:55.821613
# loss: 0.719658  [15488/15499]
# Validation Error:
#  Accuracy: 38.8%, Avg loss: 0.469106. Learning rate: 0.001000. Completed epoch 1/300
#
# loss: 0.452834  [15488/15499]
# Validation Error:
#  Accuracy: 51.5%, Avg loss: 0.359969. Learning rate: 0.001000. Completed epoch 2/300
#
# loss: 0.429334  [15488/15499]
# Validation Error:
#  Accuracy: 49.3%, Avg loss: 0.370877. Learning rate: 0.001000. Completed epoch 3/300
#
# loss: 0.374665  [15488/15499]
# Validation Error:
#  Accuracy: 54.0%, Avg loss: 0.322622. Learning rate: 0.001000. Completed epoch 4/300
#
# loss: 0.370851  [15488/15499]
# Validation Error:
#  Accuracy: 57.4%, Avg loss: 0.299424. Learning rate: 0.001000. Completed epoch 5/300
#
# loss: 0.335070  [15488/15499]
# Validation Error:
#  Accuracy: 57.3%, Avg loss: 0.299837. Learning rate: 0.001000. Completed epoch 6/300
#
# loss: 0.293234  [15488/15499]
# Validation Error:
#  Accuracy: 58.2%, Avg loss: 0.288467. Learning rate: 0.001000. Completed epoch 7/300
#
# loss: 0.287520  [15488/15499]
# Validation Error:
#  Accuracy: 57.0%, Avg loss: 0.291140. Learning rate: 0.001000. Completed epoch 8/300
#
# loss: 0.273528  [15488/15499]
# Validation Error:
#  Accuracy: 58.8%, Avg loss: 0.285880. Learning rate: 0.001000. Completed epoch 9/300
#
# loss: 0.289819  [15488/15499]
# Validation Error:
#  Accuracy: 60.1%, Avg loss: 0.277865. Learning rate: 0.001000. Completed epoch 10/300
#
# loss: 0.315069  [15488/15499]
# Validation Error:
#  Accuracy: 60.3%, Avg loss: 0.273558. Learning rate: 0.001000. Completed epoch 11/300
#
# loss: 0.342185  [15488/15499]
# Validation Error:
#  Accuracy: 58.3%, Avg loss: 0.282602. Learning rate: 0.001000. Completed epoch 12/300
#
# loss: 0.369115  [15488/15499]
# Validation Error:
#  Accuracy: 60.9%, Avg loss: 0.270153. Learning rate: 0.001000. Completed epoch 13/300
#
# loss: 0.358116  [15488/15499]
# Validation Error:
#  Accuracy: 60.8%, Avg loss: 0.270417. Learning rate: 0.001000. Completed epoch 14/300
#
# loss: 0.316472  [15488/15499]
# Validation Error:
#  Accuracy: 62.4%, Avg loss: 0.260483. Learning rate: 0.001000. Completed epoch 15/300
#
# loss: 0.314361  [15488/15499]
# Validation Error:
#  Accuracy: 54.5%, Avg loss: 0.297625. Learning rate: 0.001000. Completed epoch 16/300
#
# loss: 0.283541  [15488/15499]
# Validation Error:
#  Accuracy: 62.7%, Avg loss: 0.258580. Learning rate: 0.001000. Completed epoch 17/300
#
# loss: 0.265111  [15488/15499]
# Validation Error:
#  Accuracy: 61.0%, Avg loss: 0.264274. Learning rate: 0.001000. Completed epoch 18/300
#
# loss: 0.252153  [15488/15499]
# Validation Error:
#  Accuracy: 63.3%, Avg loss: 0.262615. Learning rate: 0.001000. Completed epoch 19/300
#
# loss: 0.313168  [15488/15499]
# Validation Error:
#  Accuracy: 65.1%, Avg loss: 0.251710. Learning rate: 0.001000. Completed epoch 20/300
#
# loss: 0.255077  [15488/15499]
# Validation Error:
#  Accuracy: 58.0%, Avg loss: 0.278991. Learning rate: 0.001000. Completed epoch 23/300
#
# loss: 0.260999  [15488/15499]
# Validation Error:
#  Accuracy: 64.7%, Avg loss: 0.246254. Learning rate: 0.001000. Completed epoch 24/300
#
# loss: 0.267455  [15488/15499]
# Validation Error:
#  Accuracy: 61.9%, Avg loss: 0.261944. Learning rate: 0.001000. Completed epoch 25/300
#
# loss: 0.275799  [15488/15499]
# Validation Error:
#  Accuracy: 65.4%, Avg loss: 0.242383. Learning rate: 0.001000. Completed epoch 26/300
#
# loss: 0.244978  [15488/15499]
# Validation Error:
#  Accuracy: 64.8%, Avg loss: 0.243207. Learning rate: 0.001000. Completed epoch 27/300
#
# loss: 0.256045  [15488/15499]
# Validation Error:
#  Accuracy: 65.7%, Avg loss: 0.241045. Learning rate: 0.001000. Completed epoch 28/300
#
# loss: 0.255419  [15488/15499]
# Validation Error:
#  Accuracy: 66.2%, Avg loss: 0.236460. Learning rate: 0.001000. Completed epoch 29/300
#
# loss: 0.230904  [15488/15499]
# Validation Error:
#  Accuracy: 67.7%, Avg loss: 0.232478. Learning rate: 0.001000. Completed epoch 30/300
#
[15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.190328. Learning rate: 0.001000. Completed epoch 170/300
#
# loss: 0.189189  [15488/15499]
# Validation Error:
#  Accuracy: 68.5%, Avg loss: 0.229591. Learning rate: 0.001000. Completed epoch 171/300
#
# loss: 0.171605  [15488/15499]
# Validation Error:
#  Accuracy: 69.8%, Avg loss: 0.203675. Learning rate: 0.001000. Completed epoch 172/300
#
# loss: 0.199024  [15488/15499]
# Validation Error:
#  Accuracy: 71.5%, Avg loss: 0.192483. Learning rate: 0.001000. Completed epoch 173/300
#
# loss: 0.258320  [15488/15499]
# Validation Error:
#  Accuracy: 72.8%, Avg loss: 0.196129. Learning rate: 0.001000. Completed epoch 174/300
#
# loss: 0.201261  [15488/15499]
# Validation Error:
#  Accuracy: 72.1%, Avg loss: 0.192194. Learning rate: 0.001000. Completed epoch 175/300
#
# loss: 0.197186  [15488/15499]
# Validation Error:
#  Accuracy: 72.7%, Avg loss: 0.192365. Learning rate: 0.001000. Completed epoch 176/300
#
# loss: 0.165186  [15488/15499]
# Validation Error:
#  Accuracy: 71.5%, Avg loss: 0.206756. Learning rate: 0.001000. Completed epoch 177/300
#
# loss: 0.149455  [15488/15499]
# Validation Error:
#  Accuracy: 73.3%, Avg loss: 0.189845. Learning rate: 0.001000. Completed epoch 178/300
#
# loss: 0.165915  [15488/15499]
# Validation Error:
#  Accuracy: 72.9%, Avg loss: 0.193383. Learning rate: 0.001000. Completed epoch 179/300
#
# loss: 0.185147  [15488/15499]
# Validation Error:
#  Accuracy: 73.1%, Avg loss: 0.190648. Learning rate: 0.001000. Completed epoch 180/300
#
# loss: 0.193541  [15488/15499]
# Validation Error:
#  Accuracy: 71.3%, Avg loss: 0.198563. Learning rate: 0.001000. Completed epoch 181/300
#
# loss: 0.238276  [15488/15499]
# Validation Error:
#  Accuracy: 73.0%, Avg loss: 0.190575. Learning rate: 0.001000. Completed epoch 182/300
# loss: 0.177955  [15488/15499]
# Validation Error:
#  Accuracy: 72.3%, Avg loss: 0.193117. Learning rate: 0.001000. Completed epoch 183/300
#
# loss: 0.175960  [15488/15499]
# Validation Error:
#  Accuracy: 72.7%, Avg loss: 0.191523. Learning rate: 0.001000. Completed epoch 184/300
#
# loss: 0.185060  [15488/15499]
# Validation Error:
#  Accuracy: 71.5%, Avg loss: 0.199870. Learning rate: 0.001000. Completed epoch 185/300
#
# loss: 0.197077  [15488/15499]
# Validation Error:
#  Accuracy: 72.7%, Avg loss: 0.198547. Learning rate: 0.001000. Completed epoch 186/300
#
# loss: 0.270320  [15488/15499]
# Validation Error:
#  Accuracy: 71.8%, Avg loss: 0.196388. Learning rate: 0.001000. Completed epoch 187/300
#
# loss: 0.161933  [15488/15499]
# Validation Error:
#  Accuracy: 73.7%, Avg loss: 0.191813. Learning rate: 0.001000. Completed epoch 188/300
#
# loss: 0.290135  [15488/15499]
# Validation Error:
#  Accuracy: 69.3%, Avg loss: 0.215644. Learning rate: 0.001000. Completed epoch 189/300
#
# loss: 0.205949  [15488/15499]
# Validation Error:
#
# loss: 0.196535  [15488/15499]
# Validation Error:
#  Accuracy: 73.7%, Avg loss: 0.184006. Learning rate: 0.000100. Completed epoch 211/300
#
# loss: 0.145543  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.183317. Learning rate: 0.000100. Completed epoch 212/300
#
# loss: 0.192538  [15488/15499]
# Validation Error:
#  Accuracy: 73.9%, Avg loss: 0.184252. Learning rate: 0.000100. Completed epoch 213/300
#
# loss: 0.177101  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.183518. Learning rate: 0.000100. Completed epoch 214/300
#
# loss: 0.201257  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.183187. Learning rate: 0.000100. Completed epoch 215/300
#
# loss: 0.175441  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.183044. Learning rate: 0.000100. Completed epoch 216/300
#
# loss: 0.160215  [15488/15499]
# Validation Error:
#  Accuracy: 74.0%, Avg loss: 0.184674. Learning rate: 0.000100. Completed epoch 217/300
#
# loss: 0.213156  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.182851. Learning rate: 0.000100. Completed epoch 218/300
#
# loss: 0.160260  [15488/15499]
# Validation Error:
#  Accuracy: 73.9%, Avg loss: 0.183311. Learning rate: 0.000100. Completed epoch 219/300
#
# loss: 0.230899  [15488/15499]
# Validation Error:
#  Accuracy: 74.3%, Avg loss: 0.183150. Learning rate: 0.000100. Completed epoch 220/300
#
# loss: 0.215771  [15488/15499]
# Validation Error:
#  Accuracy: 73.9%, Avg loss: 0.182744. Learning rate: 0.000100. Completed epoch 221/300
#
# loss: 0.233857  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.182894. Learning rate: 0.000100. Completed epoch 222/300
#
# loss: 0.156213  [15488/15499]
# Validation Error:
#  Accuracy: 74.0%, Avg loss: 0.182503. Learning rate: 0.000100. Completed epoch 223/300
#
# loss: 0.195892  [15488/15499]
# Validation Error:
#  Accuracy: 74.5%, Avg loss: 0.183064. Learning rate: 0.000100. Completed epoch 224/300
#
# loss: 0.157970  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.183218. Learning rate: 0.000100. Completed epoch 225/300
#
# loss: 0.232598  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.182258. Learning rate: 0.000100. Completed epoch 226/300
#
# loss: 0.183994  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.182342. Learning rate: 0.000100. Completed epoch 227/300
#
# loss: 0.214116  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.182512. Learning rate: 0.000100. Completed epoch 228/300
#
# loss: 0.171876  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.182663. Learning rate: 0.000100. Completed epoch 229/300
#
# loss: 0.197472  [15488/15499]
# Validation Error:
#  Accuracy: 74.5%, Avg loss: 0.182244. Learning rate: 0.000100. Completed epoch 230/300
#
# loss: 0.205916  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.183654. Learning rate: 0.000100. Completed epoch 231/300
#
# loss: 0.161540  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.182458. Learning rate: 0.000100. Completed epoch 232/300
#
# loss: 0.185773  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.183299. Learning rate: 0.000100. Completed epoch 233/300
#
# loss: 0.155372  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.182206. Learning rate: 0.000100. Completed epoch 234/300
#
# loss: 0.218216  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.182312. Learning rate: 0.000100. Completed epoch 235/300
#
# loss: 0.153110  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.182479. Learning rate: 0.000100. Completed epoch 236/300
#
# loss: 0.232018  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.182143. Learning rate: 0.000100. Completed epoch 237/300
#
# loss: 0.176083  [15488/15499]
# Validation Error:
#  Accuracy: 73.5%, Avg loss: 0.182977. Learning rate: 0.000100. Completed epoch 238/300
#
# loss: 0.211296  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.181472. Learning rate: 0.000100. Completed epoch 239/300
#
# loss: 0.224454  [15488/15499]
# Validation Error:
#  Accuracy: 74.4%, Avg loss: 0.181879. Learning rate: 0.000100. Completed epoch 240/300
#
# loss: 0.156536  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.182380. Learning rate: 0.000100. Completed epoch 241/300
#
# loss: 0.142338  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.182119. Learning rate: 0.000100. Completed epoch 242/300
# loss: 0.236301  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.181569. Learning rate: 0.000100. Completed epoch 243/300
#
# loss: 0.138507  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.182764. Learning rate: 0.000100. Completed epoch 244/300
#
# loss: 0.168008  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.182172. Learning rate: 0.000100. Completed epoch 245/300
#
# loss: 0.266424  [15488/15499]
# Validation Error:
#  Accuracy: 74.2%, Avg loss: 0.184624. Learning rate: 0.000100. Completed epoch 246/300
#
# loss: 0.211180  [15488/15499]
# Validation Error:
#  Accuracy: 74.3%, Avg loss: 0.181736. Learning rate: 0.000100. Completed epoch 247/300
#
# loss: 0.230630  [15488/15499]
# Validation Error:
#  Accuracy: 74.5%, Avg loss: 0.181698. Learning rate: 0.000100. Completed epoch 248/300
#
# loss: 0.226426  [15488/15499]
# Validation Error:
#  Accuracy: 74.1%, Avg loss: 0.182565. Learning rate: 0.000100. Completed epoch 249/300
#
# loss: 0.163120  [15488/15499]
# Validation Error:
# Validation Error:
#  Accuracy: 74.8%, Avg loss: 0.180965. Learning rate: 0.000100. Completed epoch 292/300
#
# loss: 0.228460  [15488/15499]
# Validation Error:
#  Accuracy: 74.6%, Avg loss: 0.180594. Learning rate: 0.000100. Completed epoch 293/300
#
# loss: 0.240689  [15488/15499]
# Validation Error:
#  Accuracy: 74.9%, Avg loss: 0.180323. Learning rate: 0.000100. Completed epoch 294/300
#
# loss: 0.262186  [15488/15499]
# Validation Error:
#  Accuracy: 74.0%, Avg loss: 0.180806. Learning rate: 0.000100. Completed epoch 295/300
#
# loss: 0.212733  [15488/15499]
# Validation Error:
#  Accuracy: 74.7%, Avg loss: 0.180242. Learning rate: 0.000100. Completed epoch 296/300
#
# loss: 0.180269  [15488/15499]
# Validation Error:
#  Accuracy: 74.6%, Avg loss: 0.181001. Learning rate: 0.000100. Completed epoch 297/300
#
# loss: 0.253167  [15488/15499]
# Validation Error:
#  Accuracy: 74.5%, Avg loss: 0.183106. Learning rate: 0.000100. Completed epoch 298/300
#
# loss: 0.133514  [15488/15499]
# Validation Error:
#  Accuracy: 74.6%, Avg loss: 0.180395. Learning rate: 0.000100. Completed epoch 299/300
#
# loss: 0.181622  [15488/15499]
# Validation Error:
#  Accuracy: 74.6%, Avg loss: 0.180508. Learning rate: 0.000100. Completed epoch 300/300

# %%
import numpy as np
# plot the losses
def plot_losses(train_loss, val_loss):
    t_loss = np.asarray(train_loss, dtype=float)
    v_loss = np.asarray(val_loss, dtype=float)
    epochs = range(len(train_loss))
    
    plt.figure(figsize=(24, 6), dpi=80)
    plt.plot(epochs, t_loss, "b", label="Training loss")
    plt.plot(epochs, v_loss, "r", label="Validation loss")
    plt.title("Training and Validation Losses.")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.show()
    
plot_losses(train_losses, val_losses)

# %%
from modules import train_info as ti # custom module

import importlib
importlib.reload(ti) # ensure code changes are applied (otherwise jupyter does not reimport)
# Out:
# ok
# ok
# <module 'modules.train_info' from '/home/wcunningham/biome_detector/networks/modules/train_info.py'>

# %%
# Evaluate the model

pred, labels = model.predict(training_dataloader)
accuracies_train, accuracy_train = ti.per_class_accuracies(pred, labels)

print("Overall training accuracy:", accuracy_train)
#print("Training accuracy by class:\n", accuracies_train)

pred, labels = model.predict(test_dataloader)
accuracies_test, accuracy_test = ti.per_class_accuracies(pred, labels)

print("Overall testing accuracy:", accuracy_test)
#print("Training accuracy by class:\n", accuracies_test)
# Out:
# Overall training accuracy: 0.7615573347107438
# Overall testing accuracy: 0.7424107142857143

# %%
# calculate, save, and dispay information on this run
sizes = ti.get_class_sizes(all_data.data)

# train accuracies plot
ti.plot_accuracies(accuracies_train, sizes, "Training Data Accuracies by Class Size")
# test accuracies plot
ti.plot_accuracies(accuracies_test, sizes, "Testing Data Accuracies by Class Size")

# save the data to a json file
ti.write_info(hyperparams, accuracies_train, accuracies_test, sizes)
# Out:
# 'logs/trainlog_2023-04-25T14-56-47-360310.json'

# %%
# save the model out
saving = False
if saving:
    torch.save(trained_model.state_dict(), "detector_model.pt")
