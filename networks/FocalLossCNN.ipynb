# %%
# Adapted from: Chapter 7 and 8 of Deep Learning with Pytorch by Eli Stevens (2020)
try:
    import torch as t
    import torch.nn as tnn
except ImportError:
    print("Colab users: pytorch comes preinstalled. Select Change Ru")
    print("Local users: Please install pytorch for your hardware using instructions from here: https://pytorch.org/get-started/locally/")
    print("ACG users: Please follow instructions here: https://vikasdhiman.info/ECE490-Neural-Networks/posts/0000-00-06-acg-slurm-jupyter/")
    
    raise

if t.cuda.is_available():
    DEVICE="cuda"
    t.cuda.set_device(t.device('cuda:0'))
else:
    DEVICE="cpu"

    
DTYPE = t.get_default_dtype()
print(f"Using {DEVICE=} and {DTYPE=}")
# Out:
# Using DEVICE='cuda' and DTYPE=torch.float32

# %%
# imports
import torch.nn
import torch.optim
import torchvision
from torchvision.transforms import Compose, Normalize, Resize
from torchvision.transforms.functional import to_tensor
from torch.utils.data import DataLoader, Dataset
from glob import glob
from PIL import Image
import re
import random
from pathlib import Path

# %%
# create a custom dataset for the images
class BiomeDataset(Dataset):
    """
    Dataset for the minecraft biome images
    """
    def __init__(self, data_dir: str, dir_is_paths=False, id_convert_dict=None):
        """
        Arguments:
            data_dir (str): Path to root data directory
            dir_is_paths (bool): If true, interprets data_dir as a list of images
        """
        # init transform to none
        self.transform = None

        if id_convert_dict is not None:
            self.id_to_class = id_convert_dict

        if dir_is_paths:
            self.paths = data_dir
            return
    
        # get the number of images in the dataset
        self.paths = glob(f"{data_dir}/*/*")
        dirs = glob(f"{data_dir}/*")

        self.id_to_class = {} # dictionary which converts a biome id to its class number
        self.data = []  # 2d array. First index indexes biome, second index indexes images
        for i, d in enumerate(dirs):
            self.data.append(glob(f"{d}/*"))
            self.id_to_class[int(re.search(r'[0-9]+', d)[0])] = i

        print(self.id_to_class) 
        print(len(self.id_to_class))   


    def split_data(self, percent_train: float, percent_val: float, seed: int):
        """
        Splits the Dataset per biome into three separate Datasets, 
        one for training, one for validation, and the remainder is for testing.
        """
        train = []
        val = []
        test = []

        rand = random.Random(seed) # TODO: broken af

        # for each biome, randomize the list and then split it
        for b in self.data:
            n_ims = len(b)
            rand.shuffle(b)
            ind1 = int(n_ims * percent_train)
            ind2 = int(n_ims * (percent_train +percent_val))
            train += b[:ind1]
            val += b[ind1:ind2]
            test += b[ind2:]

        return (BiomeDataset(train, dir_is_paths=True, id_convert_dict=self.id_to_class), 
            BiomeDataset(val, dir_is_paths=True, id_convert_dict=self.id_to_class),
            BiomeDataset(test, dir_is_paths=True, id_convert_dict=self.id_to_class))

    
    def get_class_sizes(self, id_to_class: dict):
        """
        Returns a list ordered by class type (0-n_classes) where each element is
        the number of classes for that type. Used by the balanced_loss.py module
        
        Uses the id_to_class dict to convert the file paths to class numbers
        """
        sizes = [0 for i in list(id_to_class.keys())] # init to zero
        for p in self.paths:
            label = int(re.search(r'[0-9]+', p)[0])
            sizes[id_to_class[label]] += 1
        return sizes
            
    
    def set_transform(self, transform):
        """
        updates the transform that the dataset will use when transforming images
        """
        self.transform = transform


    def __getitem__(self, idx):
        """
        Returns a tuple of (image: ndarray, label: int)
        """

        imname = self.paths[idx]
        image = Image.open(imname)
        image = to_tensor(image).cuda()  # converts to float tensor
        # apply transforms
        if self.transform is not None:
            image = self.transform(image)
    
        label = int(re.search(r'[0-9]+', imname)[0])
        label = self.id_to_class[label]
        return (image, label)


    def __len__(self):
        return len(self.paths)


all_data = BiomeDataset('../scraping/preprocessed_data')
# Out:
# {27: 0, 21: 1, 11: 2, 156: 3, 4: 4, 39: 5, 32: 6, 16: 7, 34: 8, 13: 9, 35: 10, 3: 11, 6: 12, 131: 13, 37: 14, 7: 15, 22: 16, 17: 17, 158: 18, 18: 19, 45: 20, 31: 21, 29: 22, 157: 23, 28: 24, 132: 25, 26: 26, 33: 27, 1: 28, 12: 29, 162: 30, 130: 31, 36: 32, 19: 33, 129: 34, 5: 35, 30: 36, 38: 37, 133: 38, 2: 39, 10: 40}
# 41

# %%
# example image from the dataset
import matplotlib.pyplot as plt
im, label = all_data[3]
plt.imshow(im.cpu().permute(1, 2, 0))

# %%
# split up the data
train_data, val_data, test_data = all_data.split_data(0.7, 0.2, 5)
train_data[0][0].shape
# Out:
# torch.Size([3, 180, 320])

# %%
# Normalize the data over each channel
DATA_INFO_FILE = "dataset_info.txt"
if Path(DATA_INFO_FILE).exists():
    print('Loading known dataset information for normalization')
    
    means = torch.Tensor([0, 0, 0])
    std = torch.Tensor([0, 0, 0])
    with open(DATA_INFO_FILE, 'r') as f:
        m = f.readline().replace('\n', '').split(' ')
        means[0] = float(m[0])
        means[1] = float(m[1])
        means[2] = float(m[2])
        s = f.readline().replace('\n', '').split(' ')
        std[0] = float(s[0])# * 4 # TODO: Temporary hack to reduce exploding gradient problems
        std[1] = float(s[1])# * 4
        std[2] = float(s[2])# * 4
        print("Loaded means", m)
        print("Loaded std", s)

else:
    # compute the means across each channel for the whole training dataset
    means = torch.Tensor([0, 0, 0]).cuda()
    for i in range(len(train_data)):
        im = train_data[i][0]
        means += torch.mean(im, dim=[1,2]) 
        if i % 1000 == 0:
            print(f"Calculating dataset means: {i}/{len(train_data)}")

    means = means / i

    print(means)

    # compute the stdev across each channel for the whole training dataset
    sumel = 0.0
    countel = 0
    for i in range(len(train_data)):
        img = train_data[i][0]
        img = (img - means.unsqueeze(1).unsqueeze(1))**2
        sumel += img.sum([1, 2])
        countel += torch.numel(img[0])
        if i % 1000 == 0:
            print(f"Calculating dataset stdevs: {i}/{len(train_data)}")

    std = torch.sqrt(sumel/countel)

    print(std)

    # save dataset info so that it doesn't need to be recalculated
    with open(DATA_INFO_FILE, 'w') as f:
        f.write(f"{means[0]} {means[1]} {means[2]}\n")
        f.write(f"{std[0]} {std[1]} {std[2]}\n")
        
# normalize the training and validation datasets based on the mean and stedv 
# of the training dataset
# IMAGE_SIZE = (720//10, 1280//10)
transform_img = Compose([
    # Resize(IMAGE_SIZE, antialias=True), # ensure all images are the proper size
    Normalize(mean=means, std=std)
])

train_data.set_transform(transform_img)
val_data.set_transform(transform_img)
test_data.set_transform(transform_img)

# get the number of instances of each class in the training set
training_class_counts = train_data.get_class_sizes(all_data.id_to_class)
print(training_class_counts)
# Out:
# Loading known dataset information for normalization
# Loaded means ['0.38232675194740295', '0.44096899032592773', '0.44938528537750244']
# Loaded std ['0.2428676337003708', '0.2687499225139618', '0.38880330324172974']
# [571, 210, 33, 16, 1906, 29, 189, 298, 428, 331, 701, 1726, 465, 54, 75, 277, 100, 331, 4, 495, 12, 62, 567, 42, 197, 88, 79, 62, 2108, 877, 75, 58, 113, 247, 121, 1117, 226, 42, 25, 1071, 71]

# %%
# now a glance at the normalized data. 
im, label = train_data[1]
print(torch.min(im))
print(torch.max(im))

plt.imshow(im.cpu().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(-1.6408, device='cuda:0')
# tensor(2.0104, device='cuda:0')

# %%
# Hyperparameters
hyperparams = {
    "batch_size": 64,
    "learning_rate": 1e-3,
    "epochs": 300,
    "momentum": 0.9,
    "weight_decay": 0.01, # The L-2 normalization penalty used by the optimizer
    "dropout_rate": 0,
    "loss_f": "FocalLoss",
    "gamma": 2,    # focal loss parameter. The paper found that gamma=2 was optimal for their network
    "beta": 0.99
}

# Create the dataloaders. drop_last=True ignores the last, incomplete batch for evaluation compatibility
training_dataloader = DataLoader(train_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)
validation_dataloader = DataLoader(val_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)
test_dataloader = DataLoader(test_data, batch_size=hyperparams['batch_size'], shuffle=True, drop_last=True)

# %%
# Model definition
from modules.losses import Loss
#loss = focalloss.FocalLoss(hyperparams['gamma'], hyperparams['alpha']) # sed for binary classification?
loss = Loss(
    loss_type="focal_loss",
    beta=hyperparams['beta'], # class-balanced loss beta
    fl_gamma=hyperparams['gamma'], 
    samples_per_class=training_class_counts,
    class_balanced=True
    )

class ConvNeuralNet(tnn.Module):
    #  Determine what layers and their order in CNN object
    # Code from https://blog.paperspace.com/writing-cnns-from-scratch-in-pytorch/
    def __init__(self, num_classes, dropout_rate):
        super(ConvNeuralNet, self).__init__()
        self.conv_layer1 = tnn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, padding='same')
        self.drop1 = tnn.Dropout(dropout_rate)
        self.conv_layer2 = tnn.Conv2d(in_channels=16, out_channels=16, kernel_size=5, padding='same')
        self.batch_norm1 = tnn.BatchNorm2d(16)
        self.max_pool1 = tnn.MaxPool2d(kernel_size = 2, stride = 2)
        
        self.conv_layer3 = tnn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same')
        self.drop2 = tnn.Dropout(dropout_rate)
        self.conv_layer4 = tnn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding='same')
        self.batch_norm2 = tnn.BatchNorm2d(32)
        self.max_pool2 = tnn.MaxPool2d(kernel_size = 2, stride = 2)

        self.conv_layer5 = tnn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding='same')
        self.drop3 = tnn.Dropout(dropout_rate)
        self.conv_layer6 = tnn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding='same')
        self.batch_norm3 = tnn.BatchNorm2d(64)
        self.max_pool3 = tnn.MaxPool2d(kernel_size = 2, stride = 2)        

        self.conv_layer7 = tnn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding='same')
        self.drop4 = tnn.Dropout(dropout_rate)
        self.conv_layer8 = tnn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding='same')
        self.batch_norm4 = tnn.BatchNorm2d(128)
        self.max_pool4 = tnn.MaxPool2d(kernel_size = 2, stride = 2)    
        
        self.fc1 = tnn.Linear(28160, 128)
        self.relu1 = tnn.ReLU()
        self.dropend = tnn.Dropout(p=0.5) # accordding to literature, in FC layers dropout=0.5 is best
        self.fc2 = tnn.Linear(128, num_classes)
    
    # Progresses data across layers    
    def forward(self, x):
        out = self.conv_layer1(x)
        out = self.drop1(out)
        out = self.conv_layer2(out)
        out = self.batch_norm1(out)
        out = self.max_pool1(out)
        
        out = self.conv_layer3(out)
        out = self.drop2(out)
        out = self.conv_layer4(out)
        out = self.batch_norm2(out)
        out = self.max_pool2(out)
        
        out = self.conv_layer5(out)
        out = self.drop3(out)
        out = self.conv_layer6(out)
        out = self.batch_norm3(out)
        out = self.max_pool3(out)

        out = self.conv_layer7(out)
        out = self.drop4(out)
        out = self.conv_layer8(out)
        out = self.batch_norm4(out)
        out = self.max_pool4(out)
        
        out = out.reshape(out.size(0), -1)
        
        out = self.fc1(out)
        out = self.relu1(out)
        out = self.dropend(out)
        out = self.fc2(out)
        return out

    # Get model results for inputs
    def step(self, inputs):
        data, labels = inputs
        outputs = self(data)
        _, preds = torch.max(outputs.data , 1)
        return preds, labels
    
    # get predictions for entire dataloader
    def predict(self, dataloader):
        predictions = torch.Tensor()
        labels = torch.Tensor()
        self.eval() # put in eval mode
        for i, batch in enumerate(dataloader):
            pred, label = self.step(batch)
            predictions = torch.cat((predictions, pred.cpu()))
            labels = torch.cat((labels, label.cpu()))
        return predictions, labels
    
    
model = ConvNeuralNet(len(training_class_counts), hyperparams['dropout_rate'])
model.cuda()

# Define optimizer
optimizer = torch.optim.SGD(model.parameters(), 
                            lr=hyperparams['learning_rate'], 
                            momentum=hyperparams['momentum'], 
                            weight_decay=hyperparams['weight_decay']
                            )

# deine learning rate scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, mode='min',
                            patience=10, factor=0.5
                            )

# check what device model is being stored on
print("Is cuda being used for the model?", all([p.is_cuda for p in model.parameters()]))
# Out:
# Is cuda being used for the model? True

# %%
from torch.utils.tensorboard import SummaryWriter
import os, datetime
writer = SummaryWriter()

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def loss_and_accuracy(model, loss, validation_dataloader, device=DEVICE):
        # Validation loop
        validation_size = len(validation_dataloader.dataset)
        num_batches = len(validation_dataloader)
        test_loss, correct = 0, 0
        
        with torch.no_grad():
            model.eval() # Put model in eval mode, affects layers like dropout and batchnorm
            for X, y in validation_dataloader:
                X = X.to(device)
                y = y.to(device)
                pred = model(X)
                test_loss += loss(pred, y)
                correct += (pred.argmax(dim=-1) == y).type(DTYPE).sum()

        test_loss /= num_batches
        correct /= validation_size
        return test_loss, correct
    
def train(model, loss, training_dataloader, validation_dataloader, epochs, device=DEVICE, chkpt_name='model_ckpt.pt', ignore_chkpt=False):
    model.to(device)
    t0 = 0
    if not ignore_chkpt and os.path.exists(f"runs/{chkpt_name}"):
        checkpoint = torch.load(f"runs/{chkpt_name}")
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        t0 = checkpoint['epoch']
        
    # Keep track of train and val losses so that we can plot it easily after the training is complete
    train_losses = []
    val_losses = []
    
    for t in range(t0, epochs):
        # Train loop
        training_size = len(training_dataloader.dataset)
        nbatches = len(training_dataloader)
        model.train() # Put model in train mode, affects layers like dropout and batchnorm
        for batch, (X, y) in enumerate(training_dataloader):
            X = X.to(device)
            y = y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss_t = loss(pred, y)

            # Backpropagation
            optimizer.zero_grad()
            loss_t.backward()
            optimizer.step()

            if batch % 1 == 0:
                writer.add_scalar("Train/loss_batch", loss_t,  t*nbatches + batch)
                loss_t, current = loss_t.item(), (batch + 1) * len(X)
                print(f"loss: {loss_t:>7f}  [{current:>5d}/{training_size:>5d}]", end="\r")
                
        writer.add_scalar("Train/loss", loss_t, t)
        valid_loss, correct = loss_and_accuracy(model, loss, validation_dataloader, device=device)
        
        # step the learning rate shceduler
        scheduler.step(valid_loss)
        
        writer.add_scalar("Valid/loss", valid_loss, t)
        writer.add_scalar("Valid/accuracy", correct, t)
        print(f"\nValidation Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {valid_loss:>8f}. Learning rate: {get_lr(optimizer):>8f}. Completed epoch {t+1}/{epochs} \n")
        
        train_losses.append(float(loss_t))
        val_losses.append(float(valid_loss))
        
        if t % 3 == 0:
            torch.save({
                'epoch': t,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict()
                }, f"runs/{chkpt_name}")
    return model, train_losses, val_losses
        
    
print(f"Training model using device {DEVICE}. Started at {datetime.datetime.now()}")
trained_model, train_losses, val_losses = train(model, loss, training_dataloader, validation_dataloader, 
                    hyperparams['epochs'], chkpt_name='linear_model_chkpt.pt', ignore_chkpt=True)
# Out:
# Training model using device cuda. Started at 2023-04-25 15:35:24.009190
# loss: 0.568021  [15488/15499]
# Validation Error:
#  Accuracy: 30.1%, Avg loss: 0.682729. Learning rate: 0.001000. Completed epoch 2/300
#
# loss: 0.384147  [15488/15499]
# Validation Error:
#  Accuracy: 32.4%, Avg loss: 0.693150. Learning rate: 0.001000. Completed epoch 3/300
#
# loss: 0.368456  [15488/15499]
# Validation Error:
#  Accuracy: 31.5%, Avg loss: 0.804917. Learning rate: 0.001000. Completed epoch 4/300
#
# loss: 0.373519  [15488/15499]
# Validation Error:
#  Accuracy: 26.3%, Avg loss: 0.855908. Learning rate: 0.001000. Completed epoch 5/300
#
# loss: 0.369796  [15488/15499]
# Validation Error:
#  Accuracy: 27.5%, Avg loss: 0.880795. Learning rate: 0.001000. Completed epoch 6/300
#
# loss: 0.312323  [15488/15499]
# Validation Error:
#  Accuracy: 25.6%, Avg loss: 0.842682. Learning rate: 0.001000. Completed epoch 7/300
#
# loss: 0.386344  [15488/15499]
# Validation Error:
#  Accuracy: 26.7%, Avg loss: 0.926749. Learning rate: 0.001000. Completed epoch 8/300
#
# loss: 0.379213  [15488/15499]
# Validation Error:
#  Accuracy: 28.7%, Avg loss: 0.915452. Learning rate: 0.001000. Completed epoch 9/300
#
# loss: 0.410148  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 0.888675. Learning rate: 0.001000. Completed epoch 10/300
#
# loss: 0.362011  [15488/15499]
# Validation Error:
#  Accuracy: 24.5%, Avg loss: 0.951934. Learning rate: 0.001000. Completed epoch 11/300
#
# loss: 0.280647  [15488/15499]
# Validation Error:
#  Accuracy: 25.0%, Avg loss: 0.935519. Learning rate: 0.001000. Completed epoch 12/300
#
# loss: 0.314160  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.039426. Learning rate: 0.000500. Completed epoch 13/300
#
# loss: 0.295100  [15488/15499]
# Validation Error:
#  Accuracy: 20.7%, Avg loss: 1.001018. Learning rate: 0.000500. Completed epoch 14/300
#
# loss: 0.322661  [15488/15499]
# Validation Error:
#  Accuracy: 21.8%, Avg loss: 1.013149. Learning rate: 0.000500. Completed epoch 15/300
#
# loss: 0.330758  [15488/15499]
# Validation Error:
#  Accuracy: 21.4%, Avg loss: 0.995625. Learning rate: 0.000500. Completed epoch 16/300
#
# loss: 0.268868  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.018742. Learning rate: 0.000500. Completed epoch 17/300
#
# loss: 0.262505  [15488/15499]
# Validation Error:
#  Accuracy: 26.8%, Avg loss: 0.939366. Learning rate: 0.000500. Completed epoch 18/300
#
# loss: 0.355713  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 0.995304. Learning rate: 0.000500. Completed epoch 19/300
#
# loss: 0.336207  [15488/15499]
# Validation Error:
#  Accuracy: 17.5%, Avg loss: 1.115914. Learning rate: 0.000500. Completed epoch 20/300
#
# loss: 0.294219  [15488/15499]
# Validation Error:
#  Accuracy: 22.8%, Avg loss: 1.083184. Learning rate: 0.000500. Completed epoch 21/300
#
# loss: 0.252244  [15488/15499]
# Validation Error:
#  Accuracy: 18.7%, Avg loss: 1.071986. Learning rate: 0.000500. Completed epoch 22/300
#
# loss: 0.291284  [15488/15499]
# Validation Error:
#  Accuracy: 14.9%, Avg loss: 1.103234. Learning rate: 0.000500. Completed epoch 23/300
#
# loss: 0.239922  [15488/15499]
# Validation Error:
#  Accuracy: 21.5%, Avg loss: 1.035853. Learning rate: 0.000250. Completed epoch 24/300
#
# loss: 0.300093  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.050659. Learning rate: 0.000250. Completed epoch 25/300
#
# loss: 0.296939  [15488/15499]
# Validation Error:
#  Accuracy: 19.0%, Avg loss: 1.061633. Learning rate: 0.000250. Completed epoch 26/300
#
# loss: 0.268554  [ 8512/15499]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# loss: 0.259721  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1
#  Accuracy: 23.7%, Avg loss: 1.119036. Learning rate: 0.000000. Completed epoch 132/300
#
# loss: 0.306133  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.096575. Learning rate: 0.000000. Completed epoch 133/300
#
# loss: 0.316441  [15488/15499]
# Validation Error:
#  Accuracy: 23.0%, Avg loss: 1.109334. Learning rate: 0.000000. Completed epoch 134/300
#
# loss: 0.246252  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.106864. Learning rate: 0.000000. Completed epoch 135/300
#
# loss: 0.241002  [15488/15499]
# Validation Error:
#  Accuracy: 24.2%, Avg loss: 1.116286. Learning rate: 0.000000. Completed epoch 136/300
#
# loss: 0.292448  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.127438. Learning rate: 0.000000. Completed epoch 137/300
#
# loss: 0.305623  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.111811. Learning rate: 0.000000. Completed epoch 138/300
#
# loss: 0.269587  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.137983. Learning rate: 0.000000. Completed epoch 139/300
#
# loss: 0.250964  [15488/15499]
# Validation Error:
#  Accuracy: 22.8%, Avg loss: 1.132645. Learning rate: 0.000000. Completed epoch 140/300
#
# loss: 0.302100  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.110073. Learning rate: 0.000000. Completed epoch 141/300
#
# loss: 0.269699  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.117376. Learning rate: 0.000000. Completed epoch 142/300
#
# loss: 0.295752  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.122299. Learning rate: 0.000000. Completed epoch 143/300
#
# loss: 0.259809  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.110287. Learning rate: 0.000000. Completed epoch 144/300
#
# loss: 0.249564  [15488/15499]
# Validation Error:
#  Accuracy: 24.5%, Avg loss: 1.092965. Learning rate: 0.000000. Completed epoch 145/300
#
# loss: 0.284477  [15488/15499]
# Validation Error:
#  Accuracy: 22.9%, Avg loss: 1.103071. Learning rate: 0.000000. Completed epoch 146/300
#
# loss: 0.220524  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.132408. Learning rate: 0.000000. Completed epoch 147/300
#
# loss: 0.298198  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.118403. Learning rate: 0.000000. Completed epoch 148/300
#
# loss: 0.267778  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.118638. Learning rate: 0.000000. Completed epoch 149/300
#
# loss: 0.216792  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.117570. Learning rate: 0.000000. Completed epoch 150/300
#
# loss: 0.261577  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.114404. Learning rate: 0.000000. Completed epoch 151/300
#
# loss: 0.341035  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.086996. Learning rate: 0.000000. Completed epoch 152/300
#
# loss: 0.255069  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.121683. Learning rate: 0.000000. Completed epoch 153/300
#
# loss: 0.221768  [15488/15499]
# Validation Error:
#  Accuracy: 24.0%, Avg loss: 1.097819. Learning rate: 0.000000. Completed epoch 154/300
#
# loss: 0.232910  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.116921. Learning rate: 0.000000. Completed epoch 155/300
#
# loss: 0.281510  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.121896. Learning rate: 0.000000. Completed epoch 156/300
#
# loss: 0.298140  [15488/15499]
# Validation Error:
#  Accuracy: 24.0%, Avg loss: 1.121593. Learning rate: 0.000000. Completed epoch 157/300
#
# loss: 0.280265  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.110140. Learning rate: 0.000000. Completed epoch 158/300
#
# loss: 0.304988  [15488/15499]
# Validation Error:
#  Accuracy: 22.8%, Avg loss: 1.108270. Learning rate: 0.000000. Completed epoch 159/300
#
# loss: 0.229397  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.120347. Learning rate: 0.000000. Completed epoch 160/300
#
# loss: 0.287148  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.112121. Learning rate: 0.000000. Completed epoch 161/300
#
# loss: 0.268393  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.127578. Learning rate: 0.000000. Completed epoch 162/300
#
# loss: 0.324050  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.135063. Learning rate: 0.000000. Completed epoch 163/300
#
# loss: 0.299748  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.117013. Learning rate: 0.000000. Completed epoch 164/300
#
# loss: 0.223642  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.111005. Learning rate: 0.000000. Completed epoch 165/300
#
# loss: 0.292611  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.105758. Learning rate: 0.000000. Completed epoch 166/300
#
# loss: 0.235587  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.097337. Learning rate: 0.000000. Completed epoch 167/300
#
# loss: 0.207972  [15488/15499]
# Validation Error:
#  Accuracy: 23.0%, Avg loss: 1.125631. Learning rate: 0.000000. Completed epoch 168/300
#
# loss: 0.236626  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.140041. Learning rate: 0.000000. Completed epoch 169/300
# loss: 0.300290  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.130724. Learning rate: 0.000000. Completed epoch 170/300
#
# loss: 0.249889  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.131676. Learning rate: 0.000000. Completed epoch 171/300
#
# loss: 0.221276  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.107577. Learning rate: 0.000000. Completed epoch 172/300
#
# loss: 0.242905  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.117292. Learning rate: 0.000000. Completed epoch 173/300
#
# loss: 0.380627  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.112496. Learning rate: 0.000000. Completed epoch 174/300
#
# loss: 0.254339  [15488/15499]
# Validation Error:
#  Accuracy: 24.1%, Avg loss: 1.133692. Learning rate: 0.000000. Completed epoch 175/300
#
# loss: 0.276333  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.144291. Learning rate: 0.000000. Completed epoch 176/300
#
# loss: 0.258462  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.137639. Learning rate: 0.000000. Completed epoch 177/300
#
# loss: 0.257096  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.122257. Learning rate: 0.000000. Completed epoch 178/300
#
# loss: 0.240223  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.119070. Learning rate: 0.000000. Completed epoch 179/300
#
# loss: 0.260388  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.097080. Learning rate: 0.000000. Completed epoch 180/300
#
# loss: 0.256009  [15488/15499]
# Validation Error:
#  Accuracy: 24.2%, Avg loss: 1.110540. Learning rate: 0.000000. Completed epoch 181/300
#
# loss: 0.286726  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.113541. Learning rate: 0.000000. Completed epoch 182/300
#
# loss: 0.265529  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.104784. Learning rate: 0.000000. Completed epoch 183/300
#
# loss: 0.250120  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.111451. Learning rate: 0.000000. Completed epoch 184/300
#
# loss: 0.251782  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.129441. Learning rate: 0.000000. Completed epoch 185/300
#
# loss: 0.253079  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.136403. Learning rate: 0.000000. Completed epoch 186/300
#
# loss: 0.295914  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.127025. Learning rate: 0.000000. Completed epoch 187/300
#
# loss: 0.285677  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.108460. Learning rate: 0.000000. Completed epoch 188/300
#
# loss: 0.274539  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.118366. Learning rate: 0.000000. Completed epoch 189/300
#
# loss: 0.216956  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.119185. Learning rate: 0.000000. Completed epoch 190/300
#
# loss: 0.213990  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.139766. Learning rate: 0.000000. Completed epoch 191/300
#
# loss: 0.257236  [15488/15499]
# Validation Error:
#  Accuracy: 22.7%, Avg loss: 1.124624. Learning rate: 0.000000. Completed epoch 192/300
#
# loss: 0.244918  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.116444. Learning rate: 0.000000. Completed epoch 193/300
#
# loss: 0.243309  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.106443. Learning rate: 0.000000. Completed epoch 194/300
#
# loss: 0.235956  [15488/15499]
# Validation Error:
#  Accuracy: 23.9%, Avg loss: 1.102063. Learning rate: 0.000000. Completed epoch 195/300
#
# loss: 0.252826  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.114599. Learning rate: 0.000000. Completed epoch 196/300
#
# loss: 0.253531  [15488/15499]
# Validation Error:
#  Accuracy: 23.9%, Avg loss: 1.127095. Learning rate: 0.000000. Completed epoch 197/300
#
# loss: 0.256202  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.145376. Learning rate: 0.000000. Completed epoch 198/300
#
# loss: 0.234452  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.131172. Learning rate: 0.000000. Completed epoch 199/300
#
# loss: 0.232647  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.133577. Learning rate: 0.000000. Completed epoch 200/300
#
# loss: 0.291470  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.107044. Learning rate: 0.000000. Completed epoch 201/300
#
# loss: 0.232956  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.121875. Learning rate: 0.000000. Completed epoch 202/300
#
# loss: 0.230157  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.139090. Learning rate: 0.000000. Completed epoch 203/300
#
# loss: 0.307862  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.110789. Learning rate: 0.000000. Completed epoch 204/300
#
# loss: 0.262642  [15488/15499]
# Validation Error:
#  Accuracy: 23.9%, Avg loss: 1.093747. Learning rate: 0.000000. Completed epoch 205/300
#
# loss: 0.302226  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.110470. Learning rate: 0.000000. Completed epoch 206/300
#
# loss: 0.206296  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.111514. Learning rate: 0.000000. Completed epoch 207/300
#
# loss: 0.195517  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.121416. Learning rate: 0.000000. Completed epoch 208/300
#
# loss: 0.302928  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.096939. Learning rate: 0.000000. Completed epoch 209/300
#
# loss: 0.257807  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.130780. Learning rate: 0.000000. Completed epoch 210/300
#
# loss: 0.238454  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.109756. Learning rate: 0.000000. Completed epoch 211/300
#
# loss: 0.259227  [15488/15499]
# Validation Error:
#  Accuracy: 23.0%, Avg loss: 1.106126. Learning rate: 0.000000. Completed epoch 212/300
#
# loss: 0.271811  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.124862. Learning rate: 0.000000. Completed epoch 213/300
#
# loss: 0.323650  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.126209. Learning rate: 0.000000. Completed epoch 214/300
#
# loss: 0.258888  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.110753. Learning rate: 0.000000. Completed epoch 215/300
#
# loss: 0.183570  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.116328. Learning rate: 0.000000. Completed epoch 216/300
#
# loss: 0.255224  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.106262. Learning rate: 0.000000. Completed epoch 217/300
#
# loss: 0.298465  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.107826. Learning rate: 0.000000. Completed epoch 218/300
#
# loss: 0.259716  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.118959. Learning rate: 0.000000. Completed epoch 219/300
#
# loss: 0.269330  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.111285. Learning rate: 0.000000. Completed epoch 220/300
#
# loss: 0.311691  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.112437. Learning rate: 0.000000. Completed epoch 221/300
#
# loss: 0.246752  [15488/15499]
# Validation Error:
#  Accuracy: 24.1%, Avg loss: 1.115159. Learning rate: 0.000000. Completed epoch 222/300
#
# loss: 0.295983  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.119669. Learning rate: 0.000000. Completed epoch 223/300
#
# loss: 0.270185  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.114705. Learning rate: 0.000000. Completed epoch 224/300
#
# loss: 0.283592  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.106734. Learning rate: 0.000000. Completed epoch 225/300
#
# loss: 0.290354  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.126651. Learning rate: 0.000000. Completed epoch 226/300
#
# loss: 0.350549  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.124990. Learning rate: 0.000000. Completed epoch 227/300
#
# loss: 0.256898  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.129635. Learning rate: 0.000000. Completed epoch 228/300
#
# loss: 0.240241  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.130176. Learning rate: 0.000000. Completed epoch 229/300
# loss: 0.236933  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.097689. Learning rate: 0.000000. Completed epoch 230/300
#
# loss: 0.233394  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.149183. Learning rate: 0.000000. Completed epoch 231/300
#
# loss: 0.283570  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.122734. Learning rate: 0.000000. Completed epoch 232/300
#
# loss: 0.240560  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.118383. Learning rate: 0.000000. Completed epoch 233/300
#
# loss: 0.228625  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.106922. Learning rate: 0.000000. Completed epoch 234/300
#
# loss: 0.282994  [15488/15499]
# Validation Error:
#  Accuracy: 24.1%, Avg loss: 1.110008. Learning rate: 0.000000. Completed epoch 235/300
#
# loss: 0.273332  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.122218. Learning rate: 0.000000. Completed epoch 236/300
#
# loss: 0.284714  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.140534. Learning rate: 0.000000. Completed epoch 237/300
#
# loss: 0.293811  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.099560. Learning rate: 0.000000. Completed epoch 238/300
#
# loss: 0.286030  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.141917. Learning rate: 0.000000. Completed epoch 239/300
#
# loss: 0.276754  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.127066. Learning rate: 0.000000. Completed epoch 240/300
#
# loss: 0.216782  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.114424. Learning rate: 0.000000. Completed epoch 241/300
#
# loss: 0.239166  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.131772. Learning rate: 0.000000. Completed epoch 242/300
#
# loss: 0.290022  [15488/15499]
# Validation Error:
#  Accuracy: 24.1%, Avg loss: 1.095926. Learning rate: 0.000000. Completed epoch 243/300
#
# loss: 0.260594  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.105412. Learning rate: 0.000000. Completed epoch 244/300
#
# loss: 0.340525  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.126385. Learning rate: 0.000000. Completed epoch 245/300
#
# loss: 0.280931  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.114128. Learning rate: 0.000000. Completed epoch 246/300
#
# loss: 0.268084  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.097903. Learning rate: 0.000000. Completed epoch 247/300
#
# loss: 0.281846  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.127656. Learning rate: 0.000000. Completed epoch 248/300
#
# loss: 0.272933  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.111381. Learning rate: 0.000000. Completed epoch 249/300
#
# loss: 0.235903  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.114591. Learning rate: 0.000000. Completed epoch 250/300
#
# loss: 0.224902  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.122076. Learning rate: 0.000000. Completed epoch 251/300
#
# loss: 0.220221  [15488/15499]
# Validation Error:
#  Accuracy: 24.1%, Avg loss: 1.124382. Learning rate: 0.000000. Completed epoch 252/300
#
# loss: 0.338774  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.133177. Learning rate: 0.000000. Completed epoch 253/300
#
# loss: 0.251085  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.102582. Learning rate: 0.000000. Completed epoch 254/300
#
# loss: 0.325710  [15488/15499]
# Validation Error:
#  Accuracy: 24.0%, Avg loss: 1.110243. Learning rate: 0.000000. Completed epoch 255/300
#
# loss: 0.361772  [15488/15499]
# Validation Error:
#  Accuracy: 24.2%, Avg loss: 1.123562. Learning rate: 0.000000. Completed epoch 256/300
#
# loss: 0.230135  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.127829. Learning rate: 0.000000. Completed epoch 257/300
#
# loss: 0.282681  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.093400. Learning rate: 0.000000. Completed epoch 258/300
#
# loss: 0.230725  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.147037. Learning rate: 0.000000. Completed epoch 259/300
#
# loss: 0.283792  [15488/15499]
# Validation Error:
#  Accuracy: 23.9%, Avg loss: 1.115954. Learning rate: 0.000000. Completed epoch 260/300
#
# loss: 0.199394  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.129268. Learning rate: 0.000000. Completed epoch 261/300
#
# loss: 0.252411  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.140926. Learning rate: 0.000000. Completed epoch 262/300
#
# loss: 0.315457  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.083182. Learning rate: 0.000000. Completed epoch 263/300
#
# loss: 0.232362  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.130637. Learning rate: 0.000000. Completed epoch 264/300
#
# loss: 0.313233  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.122143. Learning rate: 0.000000. Completed epoch 265/300
#
# loss: 0.218125  [15488/15499]
# Validation Error:
#  Accuracy: 22.8%, Avg loss: 1.122165. Learning rate: 0.000000. Completed epoch 266/300
#
# loss: 0.328801  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.117755. Learning rate: 0.000000. Completed epoch 267/300
#
# loss: 0.230061  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.126776. Learning rate: 0.000000. Completed epoch 268/300
#
# loss: 0.264491  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.109675. Learning rate: 0.000000. Completed epoch 269/300
#
# loss: 0.243725  [15488/15499]
# Validation Error:
#  Accuracy: 23.9%, Avg loss: 1.116818. Learning rate: 0.000000. Completed epoch 270/300
#
# loss: 0.293386  [15488/15499]
# Validation Error:
#  Accuracy: 24.1%, Avg loss: 1.137718. Learning rate: 0.000000. Completed epoch 271/300
#
# loss: 0.314874  [15488/15499]
# Validation Error:
#  Accuracy: 22.9%, Avg loss: 1.119481. Learning rate: 0.000000. Completed epoch 272/300
#
# loss: 0.235061  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.122944. Learning rate: 0.000000. Completed epoch 273/300
#
# loss: 0.279856  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.124945. Learning rate: 0.000000. Completed epoch 274/300
#
# loss: 0.320321  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.108943. Learning rate: 0.000000. Completed epoch 275/300
#
# loss: 0.306441  [15488/15499]
# Validation Error:
#  Accuracy: 22.8%, Avg loss: 1.121950. Learning rate: 0.000000. Completed epoch 276/300
#
# loss: 0.275266  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.095584. Learning rate: 0.000000. Completed epoch 277/300
#
# loss: 0.264907  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.097209. Learning rate: 0.000000. Completed epoch 278/300
#
# loss: 0.273635  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.108437. Learning rate: 0.000000. Completed epoch 279/300
#
# loss: 0.253156  [15488/15499]
# Validation Error:
#  Accuracy: 23.6%, Avg loss: 1.118981. Learning rate: 0.000000. Completed epoch 280/300
#
# loss: 0.221323  [15488/15499]
# Validation Error:
#  Accuracy: 24.0%, Avg loss: 1.102394. Learning rate: 0.000000. Completed epoch 281/300
#
# loss: 0.297423  [15488/15499]
# Validation Error:
#  Accuracy: 22.8%, Avg loss: 1.140064. Learning rate: 0.000000. Completed epoch 282/300
#
# loss: 0.250997  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.118985. Learning rate: 0.000000. Completed epoch 283/300
#
# loss: 0.251152  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.097031. Learning rate: 0.000000. Completed epoch 284/300
#
# loss: 0.261718  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.117223. Learning rate: 0.000000. Completed epoch 285/300
#
# loss: 0.270200  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.110522. Learning rate: 0.000000. Completed epoch 286/300
#
# loss: 0.326059  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.123794. Learning rate: 0.000000. Completed epoch 287/300
#
# loss: 0.274898  [15488/15499]
# Validation Error:
#  Accuracy: 23.7%, Avg loss: 1.120942. Learning rate: 0.000000. Completed epoch 288/300
#
# loss: 0.383028  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.116995. Learning rate: 0.000000. Completed epoch 289/300
# loss: 0.271600  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.126829. Learning rate: 0.000000. Completed epoch 290/300
#
# loss: 0.257479  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.121622. Learning rate: 0.000000. Completed epoch 291/300
#
# loss: 0.240621  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.091473. Learning rate: 0.000000. Completed epoch 292/300
#
# loss: 0.249753  [15488/15499]
# Validation Error:
#  Accuracy: 23.5%, Avg loss: 1.110817. Learning rate: 0.000000. Completed epoch 293/300
#
# loss: 0.367315  [15488/15499]
# Validation Error:
#  Accuracy: 23.9%, Avg loss: 1.120255. Learning rate: 0.000000. Completed epoch 294/300
#
# loss: 0.297953  [15488/15499]
# Validation Error:
#  Accuracy: 23.8%, Avg loss: 1.116644. Learning rate: 0.000000. Completed epoch 295/300
#
# loss: 0.329554  [15488/15499]
# Validation Error:
#  Accuracy: 23.3%, Avg loss: 1.127739. Learning rate: 0.000000. Completed epoch 296/300
#
# loss: 0.298927  [15488/15499]
# Validation Error:
#  Accuracy: 23.4%, Avg loss: 1.110840. Learning rate: 0.000000. Completed epoch 297/300
#
# loss: 0.366421  [15488/15499]
# Validation Error:
#  Accuracy: 23.2%, Avg loss: 1.130723. Learning rate: 0.000000. Completed epoch 298/300
#
# loss: 0.264368  [15488/15499]
# Validation Error:
#  Accuracy: 23.1%, Avg loss: 1.144676. Learning rate: 0.000000. Completed epoch 299/300
#
# loss: 0.239839  [15488/15499]
# Validation Error:
#  Accuracy: 23.0%, Avg loss: 1.123798. Learning rate: 0.000000. Completed epoch 300/300

# %%
import numpy as np
# plot the losses
def plot_losses(train_loss, val_loss):
    t_loss = np.asarray(train_loss, dtype=float)
    v_loss = np.asarray(val_loss, dtype=float)
    epochs = range(len(train_loss))
    
    plt.figure(figsize=(24, 6), dpi=80)
    plt.plot(epochs, t_loss, "b", label="Training loss")
    plt.plot(epochs, v_loss, "r", label="Validation loss")
    plt.title("Training and Validation Losses.")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.show()
    
plot_losses(train_losses, val_losses)

# %%
from modules import train_info as ti # custom module

import importlib
importlib.reload(ti) # ensure code changes are applied (otherwise jupyter does not reimport)
# Out:
# ok
# ok
# <module 'modules.train_info' from '/home/wcunningham/biome_detector/networks/modules/train_info.py'>

# %%
# Evaluate the model

pred, labels = model.predict(training_dataloader)
accuracies_train, accuracy_train = ti.per_class_accuracies(pred, labels)

print("Overall training accuracy:", accuracy_train)
#print("Training accuracy by class:\n", accuracies_train)

pred, labels = model.predict(test_dataloader)
accuracies_test, accuracy_test = ti.per_class_accuracies(pred, labels)

print("Overall testing accuracy:", accuracy_test)
#print("Training accuracy by class:\n", accuracies_test)
# Out:
# Overall training accuracy: 0.23456869834710745
# Overall testing accuracy: 0.23169642857142858

# %%
# calculate, save, and dispay information on this run
sizes = ti.get_class_sizes(all_data.data)

# train accuracies plot
ti.plot_accuracies(accuracies_train, sizes, "Training Data Accuracies by Class Size")
# test accuracies plot
ti.plot_accuracies(accuracies_test, sizes, "Testing Data Accuracies by Class Size")

# save the data to a json file
ti.write_info(hyperparams, accuracies_train, accuracies_test, sizes)
# Out:
# 'logs/trainlog_2023-04-25T19-49-55-622822.json'

# %%
# save the model out
saving = False
if saving:
    torch.save(trained_model.state_dict(), "detector_model.pt")
